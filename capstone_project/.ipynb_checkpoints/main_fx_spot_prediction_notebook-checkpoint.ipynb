# %% [markdown]
# # Machine learning capstone project - fx spot prediction
#
# The goal is to create features that can help predict the bid price, using a lookback period of a few minutes.
#
# Try to include the bid offer spread - from the benchmark model it seems volume is not an important feature so it is not a problem that i dont have this data point.
#
# I took inspiration from : https://www.kaggle.com/kimy07/eurusd-15-minute-interval-price-prediction/notebook
#
# Introduction
# This notebook trains a LSTM model that predicts the bid price of EURUSD 15 minutes in the future by looking at last five hours of data. While there is no requirement for the input to be contiguous, it's been empirically observed that having the contiguous input does improve the accuracy of the model. I suspect that having day of the week and hour of the day as the features mitigates some of the seasonality and contiguousness problems.
#
# Disclaimer: This exercise has been carried out using a small sample data which only contains 14880 samples (2015-12-29 00:00:00 to 2016-05-31 23:45:00) and lacks ASK prices. Which restricts the ability for the model to approach a better accuracy.
#
# I will use 1 year of data, from 1Jan16 to 1Jan17, also in 15 minute intervals, but with tick data features.
#
# Improvements
#
# To tune the model further, I would recommend having at least 5 years worth of data, have ASK price (so that you can compute the spread), and increasing the epoch to 3000.
# Adding more cross-axial features. Such as spread.
# If you are looking into classification approach (PASS, BUY, SELL), consider adding some technical indicators that is more sensitive to more recent data.
# Consider adding non-numerical data, e.g. news, Tweets. The catch is that you have to get the data under one minute for trading, otherwise the news will be reflected before you even make a trade. If anybody knows how to get the news streamed really fast, please let me know.
#
# Credits : Dave Y. Kim, Mahmoud Elsaftawy,

# %% [markdown]
# To run on EC2:
# - Enter the repo directory: cd aind2-cnn
# - Activate the new environment: source activate aind2
# - Start Jupyter: jupyter notebook --ip=0.0.0.0 --no-browser
# - Find this line in output and copy url to browser:
# - Copy/paste this URL into your browser when you connect for the first time to login with a token: http://0.0.0.0:8888/?token=3156e...
# - change the 0.0.0.0 with EC2 IP.
# - you should see the checked out repository

# %%
import pandas as pd, numpy as np
import pypyodbc
import io, datetime, os, dill
import matplotlib.colors as colors, matplotlib.cm as cm, pylab, matplotlib.pyplot as plt
from collections import OrderedDict
from sklearn.model_selection import train_test_split

import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

from subprocess import check_output
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
import pypyodbc
display(HTML("""<script>
  
    $('.ctb_hideshow').css({'display': 'block'});
    
    </script>
 """))
# Out:
# <script>
#
#     $('.ctb_hideshow').css({'display': 'block'});
#
#     </script>

# %%
initval = True

# %%
#kaggle dates: 2015-12-29 00:00:00 to 2016-05-31 23:45:00
min_date = "29Dec15"
max_date = "31May16"

if initval:
    rerunSQL = False
    log = True
    useKaggle = False
    runLSTMBinary = False
    simname = "bm_with_lookback_5_epochs_500"
    sim_desc = """
    kaggle params with my dataset
    """

# %%
import subprocess
def df_to_image(df, imgpath, filename):
    #dfplot.style.background_gradient(cmap='viridis', low=.5)

    #np.random.seed(123)
    #df = pd.DataFrame(np.random.randn(10, 5), columns=list('abcde'))


    # def hover(hover_color="#ffff99"):
    #     return dict(selector="tr:hover",
    #                 props=[("background-color", "%s" % hover_color)])

    # styles = [
    #     hover(),
    #     dict(selector="th", props=[("font-size", "150%"),
    #                                ("text-align", "center")]),
    #     dict(selector="caption", props=[("caption-side", "bottom")])
    # ]
    # html = (dfplot.style.set_table_styles(styles)
    #           .set_caption("Hover to highlight."))



    # #html = dfplot.style.render()
    # html = html.render()


    HEADER = """
    <html>
        <head>
            <style>
                .df tbody tr:nth-child(even) { background-color: #f5f5f5; }
            </style>
        </head>
        <body>
    """
    FOOTER = """
        </body>
    </html>
    """


    # dfplot.to_html('report graphs/simlog.html'
    #                , classes=['rendered_html', 'output_html', 'output_result'])
    with open(imgpath+filename+'.html', 'w') as f:
         f.write(HEADER)
         f.write(df.to_html(classes=['df', 'rendered_html']))
         f.write(FOOTER)
    return subprocess.call(
         'wkhtmltoimage -f png --width 800 "'+imgpath+filename+'.html" "'+imgpath+filename+'.png"', shell=True)

# %% [markdown]
# # Load data

# %%
if log:
    #log = {"simname": ["mine_initial", simname], "sim_desc": ["kaggle params", sim_desc]}
    #df_log = pd.DataFrame(log)
    if os.path.isfile("sim_log.xlsx"):
        df_log = pd.read_excel("sim_log.xlsx")
        df_log.loc[len(df_log)]= [simname, sim_desc] 
        df_log.to_excel("sim_log.xlsx")

# %%
display(pd.read_excel("sim_log.xlsx"))
display(pd.read_excel("log_results.xlsx").T)
# Out:
#                    simname                                   sim_desc
# 0                    dummy                                      dummy
# 1                kaggle_bm                  \n    kaggle params\n
# 2  kaggle param my dataset  \n    kaggle params with my dataset\n
#                                                                            0  \
# simname                                             kaggle linear regression
# sim_desc                                               kaggle 1 row lookback
# MSE                                                              7.78252e-06
# MAE                                                               0.00233305
# count                                                                    149
# mean                                                              0.00230515
# std                                                               0.00157654
# min                                                              -0.00105977
# 25%                                                              0.000746131
# 50%                                                               0.00332856
# 75%                                                               0.00366473
# max                                                               0.00449979
# mse train                                                        0.000406284
# mse test                                                         7.78252e-06
# mae train                                                          0.0172825
# mae test                                                          0.00233305
# how often sign of price change is same                              0.389262
# if same sign, how often are actual returns bett...                   70.6897
# if same sign, how often are actual returns bett...                       100
# if not same sign, how often is actual worse tha...                         1
# if not same sign, how often is actual worse tha...                   0.32967
#
#                                                                                                     1  \
# simname                                                                                     bm_kaggle
# sim_desc                                            kaggle bm has 200 epoch and batch size 500 and...
# MSE                                                                                       1.20446e-07
# MAE                                                                                       0.000278994
# count                                                                                             149
# mean                                                                                      9.99558e-05
# std                                                                                       0.000333468
# min                                                                                       -0.00100839
# 25%                                                                                       -0.00011158
# 50%                                                                                       0.000176191
# 75%                                                                                       0.000239134
# max                                                                                       0.000836968
# mse train                                                                                 5.39973e-07
# mse test                                                                                  1.20446e-07
# mae train                                                                                 0.000453188
# mae test                                                                                  0.000278994
# how often sign of price change is same                                                       0.657718
# if same sign, how often are actual returns bett...                                            92.8571
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                           0.960784
# if not same sign, how often is actual worse tha...                                           0.117647
#
#                                                                                                     2  \
# simname                                                     kaggle param my dataset linear regression
# sim_desc                                            \n    kaggle params with my dataset\n     1 ro...
# MSE                                                                                       6.54157e-08
# MAE                                                                                       0.000202497
# count                                                                                             103
# mean                                                                                     -2.86507e-05
# std                                                                                       0.000255398
# min                                                                                      -0.000780582
# 25%                                                                                      -0.000195682
# 50%                                                                                      -2.80142e-05
# 75%                                                                                       0.000116408
# max                                                                                       0.000529885
# mse train                                                                                 4.45437e-07
# mse test                                                                                  6.54157e-08
# mae train                                                                                 0.000426892
# mae test                                                                                  0.000202497
# how often sign of price change is same                                                       0.533981
# if same sign, how often are actual returns bett...                                            67.2727
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                              0.625
# if not same sign, how often is actual worse tha...                                           0.604167
#
#                                                                                                     3
# simname                                                                       kaggle param my dataset
# sim_desc                                            kaggle bm has 200 epoch and batch size 500 and...
# MSE                                                                                       2.45924e-07
# MAE                                                                                       0.000429252
# count                                                                                             102
# mean                                                                                      0.000327489
# std                                                                                        0.00037423
# min                                                                                      -0.000641942
# 25%                                                                                       0.000149757
# 50%                                                                                       0.000362039
# 75%                                                                                       0.000568122
# max                                                                                        0.00110817
# mse train                                                                                 1.45838e-06
# mse test                                                                                  2.45924e-07
# mae train                                                                                 0.000843233
# mae test                                                                                  0.000429252
# how often sign of price change is same                                                       0.872549
# if same sign, how often are actual returns bett...                                            97.7528
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                           0.923077
# if not same sign, how often is actual worse tha...                                           0.538462

# %%
# create 15 minute data - this fills the 15 minutes table
if rerunSQL:
    str_query = open("get_data.sql", "r").read() # returns prepared data
    str_query = str_query.replace("/*", "").replace("*/", "")

    df = getQueryDataframe(str_query, [min_date, max_date])

# %%
# dates only have an effect if a subset of dates is needed.
if rerunSQL:
    str_query = open("get_data_1y.sql", "r").read() # returns prepared data
    str_query = str_query.replace("/*", "").replace("*/", "")
    #print(str_query)
    df = getQueryDataframe(str_query, [min_date, max_date])
    df.head()

# %%
if rerunSQL:
    df.set_index('datestamp', inplace=True)
    df.index = pd.to_datetime(df.index) # else fill betweeen doesnt work
    print("min date", min(df.index))
    print("max date", max(df.index))

# %%
if rerunSQL:
    df.to_csv("data/eurusd_features.csv")

# %% [markdown]
# # Load data from file and create features

# %%
df = pd.read_csv("data/eurusd_features.csv")
df.set_index('datestamp', inplace=True)
df.index = pd.to_datetime(df.index) # else fill betweeen doesnt work

# %%
useKaggle=False
if useKaggle:
    # load kaggle reference dataset for comparison
    df_kaggle = pd.read_csv('data/bm_kaggle/EURUSD_15m_BID_sample.csv')
    #df_kaggle = pd.read_csv('data/bm_kaggle/EURUSD_15m_BID_01.01.2010-31.12.2016.csv')

    # Rename bid OHLC columns
    df_kaggle.rename(columns={'Time' : 'date', 'Open' : 'open_bid', 'Close' : 'close_bid', 
                       'High' : 'high_bid', 'Low' : 'low_bid', 'Volume' : 'volume'}, inplace=True)
    df_kaggle['date'] = pd.to_datetime(df_kaggle['date'], infer_datetime_format=True)
    df_kaggle.set_index('date', inplace=True)
    df_kaggle = df_kaggle.astype(float)

    simname = "bm_kaggle"

    df = df_kaggle
    print("min date", min(df.index))
    print("max date", max(df.index))

# %%
df.count()
# Out:
# year                           10204
# month                          10204
# day                            10204
# hour                           10204
# weekday                        10204
# 15_min                         10204
# high_bid                       10204
# low_bid                        10204
# avg_bo_spread                  10204
# nb_ticks                       10204
# open_bid                       10204
# close_bid                      10204
# last_10_tick_avg_bid_return    10204
# last_10_tick_avg_bo_spread     10204
# dtype: int64

# %%
# to include seasonality as a feature
if useKaggle:
    df['hour'] = df.index.hour
    df['day']  = df.index.weekday
    df['week'] = df.index.week
    df['month'] = df.index.month
    df['momentum']  = df['volume'] * (df['open_bid'] - df['close_bid'])
    
df['avg_price'] = (df['low_bid'] + df['high_bid'])/2
df['range']     = df['high_bid'] - df['low_bid']
df['ohlc_price'] = (df['low_bid'] + df['high_bid'] + df['open_bid'] + df['close_bid'])/4
df['oc_diff']    = df['open_bid'] - df['close_bid']
if useKaggle==False:
    df['period_return'] = df.close_bid / df.open_bid

# %% [markdown]
# # Explore dataset - show some graphs

# %%
# plot close price, compare to low and high price
ax = df.plot(x=df.index, y='close_bid', c='red', figsize=(40,10))
index = [str(item) for item in df.index]
plt.fill_between(x=index, y1='low_bid',y2='high_bid', data=df, alpha=0.4)
plt.title("entire history", fontsize=30)
title="bidhistory"
plt.savefig("report graphs/"+title+"_fig.png")
plt.show()

# plot first 200 entries 
p = df[:200].copy()
ax = p.plot(x=p.index, y='close_bid', c='red', figsize=(40,10))
index = [str(item) for item in p.index]
plt.fill_between(x=index, y1='low_bid', y2='high_bid', data=p, alpha=0.4)
plt.title('zoomed, first 200', fontsize=30)
plt.show()

# %% [markdown]
# - there are periods where the price doesnt move, probably weekends. Maybe dont consider these for training

# %%
def pltGraph(xname, yname, irow, icol, df, xval=None, yval=None, title=None, norm_axis=None):
    x_axis_col = xname
    y_axis_col = yname
    if xval is None:
        xval = df[x_axis_col]
    if yval is None:
        yval = df[y_axis_col]
    if title is None:
        title = x_axis_col + " vs " + y_axis_col
    if norm_axis is None:
        norm_axis = "x"
  
    #print("before plot:", (title, irow, icol))
    axarr[irow, icol].scatter(xval.values, yval.values, color="green", lw=0, cmap=pylab.cm.cool, alpha=0.8, s=2)
    axarr[irow, icol].set_xlim(xval.values.min(), xval.values.max())
    axarr[irow, icol].set_ylim(yval.values.min(), yval.values.max())
    axarr[irow, icol].set_xlabel(x_axis_col)
    axarr[irow, icol].set_ylabel(yname)
    axarr[irow, icol].set_title(title)
    axarr[irow, icol].grid(False)
    
    irow,icol=get_next_irow_icol(irow,icol,axarr)
    
    return irow, icol

# %%
def get_next_irow_icol(irow, icol, axarr):
    try:
        if (irow+1 > axarr.shape[0]-1) and (icol+1 > axarr.shape[1]-1):

            raise ValueError("need more rows")

        if icol+1 > axarr.shape[1]-1:
            icol = 0
            irow +=1
        else:
            icol +=1
    except:
        pass
        # create new plot
        #fig,axarr = plt.subplots(2,2)
        
    return irow, icol

# %%
import datetime
datetime.datetime.now().time().strftime("%H%M%S")
# Out:
# '201432'

# %%
def get_new_plot_and_plot_prev(title=None):
    
    
    plt.savefig("report graphs/"+title+"_fig.png")
    
    fig, axarr = plt.subplots(2, 2, figsize=(10,10)) #1 row, 2 cols, x, y
    irow, icol = 0,0
    return fig, axarr, irow, icol

# %%
# create ohlc prices, analyse distribution, think about feature transformation and de-trending

fig, axarr = plt.subplots(2, 2, figsize=(10,10)) #1 row, 2 cols, x, y
#plt.figure(figsize=(20, 4))
irow, icol = 0,0
#fig.suptitle("frequency distributions")


sns.distplot(df.period_return-1, ax=axarr[irow, icol])
axarr[irow, icol].set_title("dist period_return")
irow,icol=get_next_irow_icol(irow,icol,axarr)

if simname != "bm_kaggle":
    
    sns.distplot(df.avg_bo_spread, ax=axarr[irow, icol])
    axarr[irow, icol].set_title("dist avg_bo_spread")
    irow,icol=get_next_irow_icol(irow,icol,axarr)
    irow,icol = pltGraph("ohlc_price", "avg_bo_spread", irow, icol, df)
    qlow, qhigh = 0.01, 0.99
    df_mask = df.loc[(df.period_return < df.period_return.quantile(qhigh) ) & (df.period_return > df.period_return.quantile(qlow)) & (df.avg_bo_spread < df.avg_bo_spread.quantile(qhigh) ) & (df.avg_bo_spread > df.avg_bo_spread.quantile(qlow)),:]
    #df_mask = df.loc[(df.period_return < df.period_return.quantile(qhigh) ) & (df.period_return > df.period_return.quantile(qlow)) & (df.avg_bo_spread < 0.0001 ) & (df.avg_bo_spread > -0.0001),:]
    irow,icol = pltGraph("period_return", "avg_bo_spread", irow, icol, df_mask)
    
    
    fig,axarr, irow, icol = get_new_plot_and_plot_prev("exp1")
    
    irow,icol = pltGraph("ohlc_price", "avg_bo_spread", irow, icol, df)
    irow,icol = pltGraph("hour", "avg_bo_spread", irow, icol, df)
    irow,icol = pltGraph("hour", "nb_ticks", irow, icol, df)
    irow,icol = pltGraph("day", "nb_ticks", irow, icol, df)
    
    fig,axarr, irow, icol = get_new_plot_and_plot_prev("exp2")
    
    df_mask = df.loc[(df.period_return < df.period_return.quantile(qhigh) ) & (df.period_return > df.period_return.quantile(qlow)),:]
    irow,icol = pltGraph("hour", "period_return", irow, icol, df_mask)
    irow,icol = pltGraph("hour", "ohlc_price", irow, icol, df)
    irow,icol = pltGraph("weekday", "period_return", irow, icol, df)
    irow,icol = pltGraph("weekday", "nb_ticks", irow, icol, df)
    
    fig,axarr, irow, icol = get_new_plot_and_plot_prev("exp3")
    
    res = df.loc[:,["weekday", "avg_bo_spread"]].groupby("weekday").std()
    res.plot(kind="bar", ax=axarr[irow, icol])
    irow,icol=get_next_irow_icol(irow,icol,axarr)
    
    irow,icol = pltGraph("weekday", "avg_bo_spread", irow, icol, df)
    
    #plt.tight_layout()    
    title = "exp4"
    plt.savefig("report graphs/"+title+"_fig.png")
    plt.show()
    

print("Nb Rows: ", df.high_bid.count())
# Out:
# Nb Rows:  10204

# %% [markdown]
# - it seems the hours with the least number of ticks have the highest bo spread. This is expected, as during low activity traders might set spreads wide to avoid surprises.
# - period return is between two closing bids, 15 minutes apart. It might be a spurious measure.
# - do i have to stick to 15 minute intervals to complete this?
# - weekday 1 seems to have higher stdev of avg bo spread

# %% [markdown]
# # Add PCA as a feature and show graphs

# %%
# Add PCA as a feature instead of for reducing the dimensionality. This improves the accuracy a bit.
from sklearn.decomposition import PCA

df_np = df.copy().values.astype('float32')
pca_features = df.columns.tolist()

pca = PCA(n_components=1)
df['pca'] = pca.fit_transform(df_np)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(10,10)) #1 row, 2 cols, x, y
irow, icol = 0,0
fig.suptitle("pca against features")

if simname != "bm_kaggle":
    
    irow,icol = pltGraph("ohlc_price", "pca", irow, icol, df)
    irow,icol = pltGraph("avg_bo_spread", "pca", irow, icol, df)
    irow,icol = pltGraph("avg_bo_spread", "ohlc_price", irow, icol, df)
    
    fig,axarr, irow, icol = get_new_plot_and_plot_prev("pca1")
    
    irow,icol = pltGraph("avg_bo_spread", "period_return", irow, icol, df)
    irow,icol = pltGraph("avg_bo_spread", "period_return", irow, icol, df, yval=df['period_return'].shift(periods=1).fillna(method="bfill"), title="avg bo spread v future period return")
    irow,icol = pltGraph("ohlc_price", "pca", irow, icol, df, xval=df['ohlc_price'].shift(periods=1).fillna(method="bfill"), title="ohlc 15 min future v pca")
       
    title = "pca2"
    plt.savefig("report graphs/"+title+"_fig.png")
    plt.show()

# %% [markdown]
# # Check feature correlation

# %%
# check feature correlation, to see what correlates with the close price
colormap = plt.cm.inferno
plt.figure(figsize=(15,15))
plt.title('Pearson correlation of features', y=1.05, size=15)
sns.heatmap(df.corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
title = "correl1"
plt.savefig("report graphs/"+title+"_fig.png")
plt.show()

plt.figure(figsize=(15,5))
corr = df.corr()
sns.heatmap(corr[corr.index == 'close_bid'], linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
title = "correl_bid"
plt.savefig("report graphs/"+title+"_fig.png")
plt.show()

# %% [markdown]
# # Create dataset function for datascience method

# %%
def check_shape(*argv):
    for el in argv:
        print(el.shape)

# %%
"""
this creates training examples and actuals for the model
if nb_lookback_rows is above 1, X will have examples each of which is a 20 row dataframe
so the regression model needs to be able to use all those rows to train on
"""

def create_training_set(df, nb_lookback_rows=1):
    
    dataX, dataY = [], [] # for training
    
    # it creates for each row a 20 row lookback dataset
    # this expands the dataset by 20 faculty
    for iRow in range(len(df)-nb_lookback_rows-1): 
        
        df_lookback_rows = df[iRow:(iRow+nb_lookback_rows)] # from example 1 to 21
        dataX.append(df_lookback_rows)
        next_row = df[iRow + nb_lookback_rows] #get example 1+20, so the next point that is to be forecasted
        dataY.append(next_row) 
    
    return np.array(dataX), np.array(dataY) # convert to numpy arrays

# %% [markdown]
# # Use Random Forest for feature importance:
# Check which feature is most important, based on predicting the next closing price using just one example as training
# Do this for each example, and check which features are the best on average
# Looking back more than 1 example for each example requires a decision how to use the features. Do recent examples features get more weight?
#
# - scale all features to range 0-1 for faster convergence
# - use random forest to find best decision tree to explain closing price

# %%
# create random forest regressor - random decision trees, like weak learner, ada boost
from sklearn.ensemble import RandomForestRegressor

# Scale and create datasets
idx_close_bid = df.columns.tolist().index('close_bid') # predict this, should it be return?
df_np = df.values.astype('float32') # so regressor can use it

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df_np) # scale features to between 0 and 1 for faster convergence

# Set look_back to 100 which is 100 ticks
# look back is 1 period, to check which features predict best a 1 period return
look_back_rows = 1 # to work with more than one, use alternative reshape
X, y = create_training_set(df_scaled, nb_lookback_rows=look_back_rows) # look back only 1 row
y = y[:,idx_close_bid]
#TODO:X = np.reshape(X, (X.shape[0], X.shape[2]* look_back_rows)) # to get back rows and columns
X = np.reshape(X, (X.shape[0], X.shape[2])) # to get back rows and columns
# extend extra rows into columns, as all the prices during lookback periodd should be used as features.

# %%
check_shape(X)
# Out:
# (10202, 20)

# %%
# fit model
forest = RandomForestRegressor(n_estimators = 100)
forest = forest.fit(X, y)

# %%
# find feature with best explanatory power to predict close price
importances = forest.feature_importances_
std = np.std([forest.feature_importances_ for forest in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1] # get indices for importances
#print(indices)

column_list = df.columns.tolist()
#print(column_list)
print("Feature ranking:")
feature_dict = OrderedDict()
for f in range(X.shape[1]-1):
    #print("%d. %s %d (%f)" % (f, column_list[indices[f]], indices[f], importances[indices[f]]))
    feature_dict[column_list[indices[f]]] = importances[indices[f]]
print(pd.DataFrame([feature_dict]).T)
# Out:
# Feature ranking:
#                                     0
# close_bid                    0.916242
# ohlc_price                   0.033118
# avg_price                    0.023285
# high_bid                     0.023194
# low_bid                      0.003000
# open_bid                     0.000560
# last_10_tick_avg_bo_spread   0.000091
# last_10_tick_avg_bid_return  0.000082
# range                        0.000061
# avg_bo_spread                0.000058
# nb_ticks                     0.000055
# pca                          0.000053
# period_return                0.000040
# oc_diff                      0.000039
# hour                         0.000037
# day                          0.000037
# weekday                      0.000021
# 15_min                       0.000017
# month                        0.000009

# %% [markdown]
# # Try linear regression
# - sklearn requires numpy arrays as input
# - check how close we can get with linear regression
# - resources: http://bigdata-madesimple.com/how-to-run-linear-regression-in-python-scikit-learn/
# - problem: my features are note independent of each other, eg ohlc price, open bid, close bid etc

# %%
# plot all against close_bid
fig, axarr = plt.subplots(2, 2, figsize=(20,10)) #1 row, 2 cols, x, y
#plt.figure(figsize=(20, 4))
irow, icol = 0,0
icol = pltGraph("ohlc_price", "close_bid", irow, icol, df)
plt.show()

# %% [markdown]
# - we may have to address feature correlation as ohlc price seems strongly correlated to close bid, as close bid is contained in it

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score

# df only
X = df.drop("close_bid", axis=1)
y = df.close_bid.shift().values
cols = X.columns


#convert to numpy first
df_np = df.copy().values.astype('float32')
X, y = create_training_set(df_np, 1)
X = np.reshape(X, (X.shape[0], X.shape[2]))
idx_close_bid = df.columns.tolist().index('close_bid') # find index of columns in dataframe
y = y[:,idx_close_bid] # select column to predict
cols = df.columns # i have all here, because close_bid is included as features


# create train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=149, shuffle=False)
check_shape(X, y, X_train, X_test, y_train, y_test)
# Out:
# (10202, 20)
# (10202,)
# (10053, 20)
# (149, 20)
# (10053,)
# (149,)

# %%
reg_lasso = linear_model.Lasso(alpha = 0.1) # Lasso takes care of regularisation
reg_linear = linear_model.LinearRegression()

reg_linear.fit(X_train, y_train)
reg_lasso.fit(X_train, y_train)


df_coeff = pd.DataFrame(columns=cols
                     , data=[list(reg_linear.coef_), list(reg_lasso.coef_)]
                     , index=["linear regression coefficients", "lasso regression coefficients"])


# predict all examples and compare to actuals
plt.scatter(reg_linear.predict(X_test), y_test)
plt.xlabel("predicted")
plt.ylabel("actual")
plt.title("predicted v actual close_bid")
plt.show()

# show regression coefficients
df_coeff = df_coeff.sort_values(by='linear regression coefficients', axis=1)
df_coeff.loc["linear regression coefficients",:]
# Out:
# oc_diff                       -0.203672
# low_bid                       -0.011571
# pca                           -0.008731
# last_10_tick_avg_bo_spread    -0.001992
# avg_price                     -0.001889
# last_10_tick_avg_bid_return   -0.001864
# hour                          -0.000033
# day                           -0.000010
# 15_min                        -0.000008
# year                           0.000000
# weekday                        0.000004
# month                          0.000015
# avg_bo_spread                  0.000690
# high_bid                       0.007836
# nb_ticks                       0.008731
# range                          0.019435
# period_return                  0.183683
# ohlc_price                     0.200048
# open_bid                       0.300181
# close_bid                      0.503863
# Name: linear regression coefficients, dtype: float64

# %% [markdown]
# - what mae is acceptible as a result? If i invest based on my prediction, and it goes the other way i lose money.
# - Therefore, check the directional error, not MAE. Compare close with next close. If my prediction - actual next close has the same sign and value of that measure, count as accurate.

# %% [markdown]
# ## Check regression errors

# %%
def check_error_metrics(df, y_train, y_test, X_train_pred, X_test_pred, y_prev):
    """
        check mse, mae and directional error. This checks regression for directional errors, which would
        probably be done better with classification.
        
        y_prev is the bid price at the end of the current period. It is compared to the predicted bid price
        at the end of the next period.
    
    """

    err_list = []
    
    pred_directions = X_test_pred - y_prev
    act_directions = y_test - y_prev
    pred_returns = X_test_pred / y_prev-1
    act_returns =  y_test / y_prev -1

    

    sign_error = np.sign(pred_directions) != np.sign(act_directions)
    actual_minus_pred = act_directions - pred_directions
    #abs_actual_minus_pred = abs(act_directions) - abs(pred_directions)
    returns_actual_minus_pred = act_returns - pred_returns # larger differences will show correctly, even if signs dont match

    # how often do you make a negative 1 percent return when a positive return was predicted

    err_list= [
        ["mse train", mean_squared_error(y_train, X_train_pred)]
        ,["mse test", mean_squared_error(y_test, X_test_pred)]
        ,["mae train", mean_absolute_error(y_train, X_train_pred)]
        ,["mae test", mean_absolute_error(y_test, X_test_pred)]
        #,["mean avg bo spread", df.avg_bo_spread.mean()] # to see how close we are to a profitable strategy
        

        ,["how often sign of price change is same", (sign_error==False).sum() / len(sign_error)]

    # if correct sign, how often larger than actual value, smaller than actual value
    # is there generally good profit when you got the direction right?
        ,["if same sign, how often are actual returns better than 1 bp absolute in both directions"
          , 100*(abs(act_returns[~sign_error]) > 0.0001).sum() / len(act_returns[~sign_error])]

    # positive surprise
        ,["if same sign, how often are actual returns better than predicted in both directions"
          , 100* (abs(returns_actual_minus_pred[~sign_error]) > 0).sum() / len(returns_actual_minus_pred[~sign_error])]

    

    # not same sign
        ,["if not same sign, how often is actual worse than -1 bp return from predicted in both directions",
         (abs(returns_actual_minus_pred[sign_error]) > 0.0001).sum() / len(returns_actual_minus_pred[sign_error])]
         
        ,["if not same sign, how often is actual worse than -1 bp return absolute in both directions",
         (abs(act_returns[sign_error]) > 0.0001).sum() / len(act_returns[sign_error])]
    ]   
    # show histogram of returns which have a sign error
    fig,axarr = plt.subplots(1,4, figsize=(20,5))
    axarr[0].hist(act_returns[sign_error], bins=40)
    axarr[0].set_title("actual returns where pred and act sign mismatches")
    title = "linreg_sign_error"
    plt.savefig("report graphs/"+title+"_fig.png")
    
    axarr[1].hist(act_returns[~sign_error], bins=40)
    axarr[1].set_title("actual returns where pred and act sign matches")
    title = "linreg_sign_match"
    plt.savefig("report graphs/"+title+"_fig.png")
    
    axarr[2].hist(pred_returns[~sign_error], bins=40)
    axarr[2].set_title("pred returns where sign matches")
    title = "linreg_pred_sign_match"
    plt.savefig("report graphs/"+title+"_fig.png")
    
    axarr[3].hist(pred_returns[sign_error], bins=40)
    axarr[3].set_title("pred returns where sign mismatches")
    title = "linreg_pred_sign_mismatch"
    plt.savefig("report graphs/"+title+"_fig.png")
    
    plt.show()
    
    df_err = pd.DataFrame(err_list)
    
    for el in err_list:
        print(el)
    
    
    return df_err

# %%
df_err = check_error_metrics(df, y_train, y_test
                             , reg_linear.predict(X_train), reg_linear.predict(X_test)
                             , X_test[:,idx_close_bid])
# Out:
# ['mse train', 4.4655454e-07]
# ['mse test', 9.721186e-08]
# ['mae train', 0.00042736967]
# ['mae test', 0.00022892664]
# ['how often sign of price change is same', 0.51006711409395977]
# ['if same sign, how often are actual returns better than 1 bp absolute in both directions', 69.736842105263165]
# ['if same sign, how often are actual returns better than predicted in both directions', 100.0]
# ['if not same sign, how often is actual worse than -1 bp return from predicted in both directions', 0.67123287671232879]
# ['if not same sign, how often is actual worse than -1 bp return absolute in both directions', 0.63013698630136983]

# %% [markdown]
# ## Show log

# %%
# log results
log=False

if log:
    
    simname_lin= simname + " linear regression"
    sim_lin_desc = sim_desc + " 1 row lookback"
    
    dict_err= OrderedDict(zip(df_err[0], df_err[1]))
    
    list_stats=OrderedDict()
    
    list_stats["simname"] = simname_lin
    list_stats["sim_desc"] = sim_lin_desc
    list_stats["MSE"] = dict_err["mse test"]
    list_stats["MAE"] = dict_err["mae test"]
    
    differences_described = pd.Series(reg_linear.predict(X_test) - y_test).describe()

    list_stats.update(OrderedDict(differences_described))
    list_stats.update(dict_err)
    
    results = pd.DataFrame([list_stats])
    #results.to_excel("log_results.xlsx")
    if os.path.isfile("log_results.xlsx"):
        log_results = pd.read_excel("log_results.xlsx")
        log_results.loc[len(log_results),:] = list_stats.values()
        log_results.to_excel("log_results.xlsx")
    #log_results

# %%
dfplot = pd.read_excel("log_results.xlsx").T
dfplot
# Out:
#                                                                            0  \
# simname                                             kaggle linear regression
# sim_desc                                               kaggle 1 row lookback
# MSE                                                              7.78252e-06
# MAE                                                               0.00233305
# count                                                                    149
# mean                                                              0.00230515
# std                                                               0.00157654
# min                                                              -0.00105977
# 25%                                                              0.000746131
# 50%                                                               0.00332856
# 75%                                                               0.00366473
# max                                                               0.00449979
# mse train                                                        0.000406284
# mse test                                                         7.78252e-06
# mae train                                                          0.0172825
# mae test                                                          0.00233305
# how often sign of price change is same                              0.389262
# if same sign, how often are actual returns bett...                   70.6897
# if same sign, how often are actual returns bett...                       100
# if not same sign, how often is actual worse tha...                         1
# if not same sign, how often is actual worse tha...                   0.32967
#
#                                                                                                     1  \
# simname                                                                                     bm_kaggle
# sim_desc                                            kaggle bm has 200 epoch and batch size 500 and...
# MSE                                                                                       1.20446e-07
# MAE                                                                                       0.000278994
# count                                                                                             149
# mean                                                                                      9.99558e-05
# std                                                                                       0.000333468
# min                                                                                       -0.00100839
# 25%                                                                                       -0.00011158
# 50%                                                                                       0.000176191
# 75%                                                                                       0.000239134
# max                                                                                       0.000836968
# mse train                                                                                 5.39973e-07
# mse test                                                                                  1.20446e-07
# mae train                                                                                 0.000453188
# mae test                                                                                  0.000278994
# how often sign of price change is same                                                       0.657718
# if same sign, how often are actual returns bett...                                            92.8571
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                           0.960784
# if not same sign, how often is actual worse tha...                                           0.117647
#
#                                                                                                     2  \
# simname                                                     kaggle param my dataset linear regression
# sim_desc                                            \n    kaggle params with my dataset\n     1 ro...
# MSE                                                                                       6.54157e-08
# MAE                                                                                       0.000202497
# count                                                                                             103
# mean                                                                                     -2.86507e-05
# std                                                                                       0.000255398
# min                                                                                      -0.000780582
# 25%                                                                                      -0.000195682
# 50%                                                                                      -2.80142e-05
# 75%                                                                                       0.000116408
# max                                                                                       0.000529885
# mse train                                                                                 4.45437e-07
# mse test                                                                                  6.54157e-08
# mae train                                                                                 0.000426892
# mae test                                                                                  0.000202497
# how often sign of price change is same                                                       0.533981
# if same sign, how often are actual returns bett...                                            67.2727
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                              0.625
# if not same sign, how often is actual worse tha...                                           0.604167
#
#                                                                                                     3  \
# simname                                                                       kaggle param my dataset
# sim_desc                                            kaggle bm has 200 epoch and batch size 500 and...
# MSE                                                                                       2.45924e-07
# MAE                                                                                       0.000429252
# count                                                                                             102
# mean                                                                                      0.000327489
# std                                                                                        0.00037423
# min                                                                                      -0.000641942
# 25%                                                                                       0.000149757
# 50%                                                                                       0.000362039
# 75%                                                                                       0.000568122
# max                                                                                        0.00110817
# mse train                                                                                 1.45838e-06
# mse test                                                                                  2.45924e-07
# mae train                                                                                 0.000843233
# mae test                                                                                  0.000429252
# how often sign of price change is same                                                       0.872549
# if same sign, how often are actual returns bett...                                            97.7528
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                           0.923077
# if not same sign, how often is actual worse tha...                                           0.538462
#
#                                                                                                     4
# simname                                                     kaggle param my dataset linear regression
# sim_desc                                            \n    kaggle params with my dataset\n     1 ro...
# MSE                                                                                       9.72119e-08
# MAE                                                                                       0.000228927
# count                                                                                             149
# mean                                                                                      9.69676e-06
# std                                                                                       0.000312688
# min                                                                                      -0.000779629
# 25%                                                                                      -0.000189185
# 50%                                                                                      -7.27177e-06
# 75%                                                                                       0.000157356
# max                                                                                        0.00164235
# mse train                                                                                 4.46555e-07
# mse test                                                                                  9.72119e-08
# mae train                                                                                  0.00042737
# mae test                                                                                  0.000228927
# how often sign of price change is same                                                       0.510067
# if same sign, how often are actual returns bett...                                            69.7368
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                           0.671233
# if not same sign, how often is actual worse tha...                                           0.630137

# %%
df_to_image(dfplot, "report graphs/", "simlog")
# Out:
# 0

# %% [markdown]
# ## Plot residuals

# %%
plt.figure(figsize=(30,10))
plt.scatter(reg_linear.predict(X_train), reg_linear.predict(X_train) - y_train, c='b', s=40, alpha=0.5)
plt.scatter(reg_linear.predict(X_test), reg_linear.predict(X_test) - y_test, c='g', s=40)
plt.hlines(y=0, xmin=1.07, xmax = 1.17)
plt.title("train v test prices vs differences")
plt.show()

# %%
print("pred: %f, actual: %f" % (reg_linear.predict(X_test[0,:].reshape(1,-1)), y_test[0]))
# Out:
# pred: 1.110527, actual: 1.110180

# %% [markdown]
# ## Try ridge regression, to be more robust to correlation in features

# %%
reg = linear_model.Ridge (alpha = .5)
reg.fit(X_train, y_train) 
reg.coef_


df_coeff = pd.DataFrame(columns=cols
                     , data=[list(reg.coef_)]
                     , index=["ridge regression coefficients"])



# predict all examples and compare to actuals
plt.scatter(reg.predict(X_test), y_test)
plt.xlabel("predicted")
plt.ylabel("actual")
plt.title("predicted v actual close_bid")
plt.show()


df_coeff.sort_values(by='ridge regression coefficients', axis=1)

print("mse train all feature: ", np.mean((reg.predict(X_train) - y_train) ** 2))
print("mse test all feature: ", np.mean((reg.predict(X_test) - y_test) ** 2))

plt.figure(figsize=(30,10))
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, c='b', s=40, alpha=0.5)
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, c='g', s=40)
plt.hlines(y=0, xmin=1.07, xmax = 1.17)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.8629402726874105e-09
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# mse train all feature:  9.51816e-07
# mse test all feature:  1.49004e-06

# %% [markdown]
# # Run LSTM Model to predict close bid in next 15 min
# - scale features to range 0-1 to speed up convergence
# - set a larger lookback windows, so LSTM has something to work with and can take a decision which part of history to prioritise
# - todo: make it do error on the sign- for that need to get the sign between next and X[bid]
# - 1% test size, 10% of 99% validation size
# - try to also predict direction. y_pred - X_test close versus y_act - X_test close

# %% [markdown]
# ## Predict sign only

# %%
if runLSTMBinary:
    # Scale and create datasets
    idx_close_bid = df.columns.tolist().index('close_bid')
    df_np = df.values.astype('float32')

    # Scale the examples
    df_scaler = MinMaxScaler(feature_range=(0, 1))
    df_scaled = df_scaler.fit_transform(df_np)

    # Scale the actuals columns, but not the real values
    y_scaler = MinMaxScaler(feature_range=(0, 1))
    t_y = df['close_bid'].values.astype('float32')
    t_y = np.reshape(t_y, (-1, 1))
    y_scaler = y_scaler.fit(t_y) # create a fitted y scaler

    # Set look_back to 20 which is 5 hours (15min*20)
    X, y_orig = create_training_set(df_scaled, nb_lookback_rows=40)
    #y_return_sign = np.sign(y[:,idx_close_bid] - X[:,0,idx_close_bid]) # these are the actuals
    y_return_sign = y_orig[:,idx_close_bid] - X[:,0,idx_close_bid] # these are the actuals
    y = np.sign(y_return_sign) # an array of -1, 1 and 0

    y = pd.get_dummies(y).values.astype('float32')



    # need to create a binarised vector, one positive class, one negative class
    #y_pred_return_sign = # comes from model

# %% [markdown]
# ## Predict exact price value

# %%
simname = "bm_with_lookback_5_epochs_500"

if not runLSTMBinary:
    # Scale and create datasets
    idx_close_bid = df.columns.tolist().index('close_bid')
    #idx_high = df.columns.tolist().index('high_bid')
    #idx_low = df.columns.tolist().index('low_bid')
    df_np = df.values.astype('float32')

    # Scale the examples
    df_scaler = MinMaxScaler(feature_range=(0, 1))
    df_scaled = df_scaler.fit_transform(df_np)

    # Scale the actuals columns, but not the real values
    y_scaler = MinMaxScaler(feature_range=(0, 1))
    t_y = df['close_bid'].values.astype('float32')
    t_y = np.reshape(t_y, (-1, 1))
    y_scaler = y_scaler.fit(t_y) # create a fitted y scaler

    # Set look_back to 20 which is 5 hours (15min*20)
    X, y = create_training_set(df_scaled, nb_lookback_rows=5) # bm kaggle is 20
    y = y[:,idx_close_bid]

# %%
# Set training data size
# We have a large enough dataset. So divid into 99% training and val (10% of those 99%) / 1% test set
import sklearn
sklearn.__version__
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =149, shuffle=False)       # hardcode to make percentages correct
check_shape(X, y, X_train, X_test, y_train, y_test)
# Out:
# (10198, 5, 20)
# (10198,)
# (10049, 5, 20)
# (149, 5, 20)
# (10049,)
# (149,)

# %%
if useKaggle:
    train_size = int(len(X) * 0.99)
    trainX = X[:train_size]
    trainY = y[:train_size]
    testX = X[train_size:]
    testY = y[train_size:]
    check_shape(X, y, X_train, X_test, y_train, y_test)

# %% [markdown]
# ## Run LSTM Model

# %%
from keras.backend import categorical_crossentropy
# ensure there is a 1st derivative! else get none error
# it will check in which direction this error goesn down and walk there
# maybe it has issue because sign is not continuous...
# just use categorical crossentropy, it does exactly what i need much better
def ret_direction_error(y_true, y_pred):
    
    # this guy puts everything into numpy before working on it https://stackoverflow.com/questions/46411573/keras-custom-loss-function-not-working
     
    out = categorical_crossentropy(y_true, y_pred)
    
    return out
    
    # y_true is y_train, y_pred is what the model gives me
    # so should set y_true to the return sign? and stop training on absolute value, but make sure sign is right

# %%
"""

kaggle:
model = Sequential()
model.add(LSTM(20, input_shape=(X.shape[1], X.shape[2]), return_sequences=True)) # does not take into account nb examples
model.add(LSTM(20, return_sequences=True))
model.add(LSTM(10, return_sequences=True))
#model.add(LSTM(10, return_sequences=True)) # a second layer of 10 really helps get the loss to 7 by 10th epoch
model.add(Dropout(0.2))
model.add(LSTM(4, return_sequences=False))
model.add(Dense(4, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='relu')) 

"""
# Out:
# "\n\nkaggle:\nmodel = Sequential()\nmodel.add(LSTM(20, input_shape=(X.shape[1], X.shape[2]), return_sequences=True)) # does not take into account nb examples\nmodel.add(LSTM(20, return_sequences=True))\nmodel.add(LSTM(10, return_sequences=True))\n#model.add(LSTM(10, return_sequences=True)) # a second layer of 10 really helps get the loss to 7 by 10th epoch\nmodel.add(Dropout(0.2))\nmodel.add(LSTM(4, return_sequences=False))\nmodel.add(Dense(4, kernel_initializer='uniform', activation='relu'))\nmodel.add(Dense(1, kernel_initializer='uniform', activation='relu')) \n\n"

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, LSTM, Dense
import keras.backend as K
import tensorflow as tf

# create a small LSTM network
# shoudl first input number match nb of lookback rows?
model = Sequential()
model.add(LSTM(20, input_shape=(X.shape[1], X.shape[2]), return_sequences=True)) # does not take into account nb examples
model.add(LSTM(20, return_sequences=True))
model.add(LSTM(10, return_sequences=True))
#model.add(LSTM(10, return_sequences=True)) # a second layer of 10 really helps get the loss to 7 by 10th epoch
model.add(Dropout(0.2))
model.add(LSTM(4, return_sequences=False))
model.add(Dense(4, kernel_initializer='uniform', activation='relu'))



# for price prediction
if not runLSTMBinary:
    model.add(Dense(1, kernel_initializer='uniform', activation='relu')) # this compresses everything to one output in the final layer
    #model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae', 'mse', 'accuracy'])
    model.compile(loss='mse', optimizer='adam', metrics=['mae', 'mse', 'accuracy'])
    
    
# for direction prediction
if runLSTMBinary:
    # need a softmax output for category predictions
    model.add(Dense(3, activation="softmax"))   

    # loss: optimises this - https://keras.io/losses/
    # loss will show up in the history under 'loss'
    model.compile(loss=ret_direction_error, optimizer='adam', metrics=['mae', 'mse', ret_direction_error, 'accuracy'])
    
#print(model.summary())
# def myprint(s):
#     simname = "kagag"
#     with open('model weights/'+simname+'model_summary.txt','w+') as f:
#         print(s, file=f)

# model.summary(print_fn=myprint)
model_json = model.to_json()
with open("model weights/"+simname+"_model.json", "w") as json_file:
    json_file.write(model_json)
print(model.summary())
with open('model weights/'+simname+'_model_summary.txt','w+') as f:
         f.write(model.to_yaml())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_89 (LSTM)               (None, 5, 20)             3280
# _________________________________________________________________
# lstm_90 (LSTM)               (None, 5, 20)             3280
# _________________________________________________________________
# lstm_91 (LSTM)               (None, 5, 10)             1240
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 5, 10)             0
# _________________________________________________________________
# lstm_92 (LSTM)               (None, 4)                 240
# _________________________________________________________________
# dense_45 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 8,065
# Trainable params: 8,065
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#simname = "500_epochs_40_lookback_pca_unshuffled_binary"
#sim_desc = "kaggle bm has 200 epoch and batch size 500 and no period return as a feature"
#simname = "bm_kaggle"
#simname = "kaggle param my dataset"

# %%
# Save the best weight during training. Cant handel custom functions for errors
from keras.callbacks import ModelCheckpoint
epoch = 500

# write custom errors as string, they seem to refer to the key in err.history dict
if not runLSTMBinary:
    #checkpoint = ModelCheckpoint(simname + ".weights.best.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint("model weights/"+simname + ".weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='min')

if runLSTMBinary:
    checkpoint = ModelCheckpoint("model weights/"+simname + ".weights.best.hdf5", monitor='val_ret_direction_error', verbose=1, save_best_only=True, mode='min')

# Fit
"""
it seems batch size controls convergence speed a lot! Batch size tells how many examples are propagated through the network.
Weights are adjusted based on results with these examples. This is useful if the full dataset takes too much memory
It also speeds up training, as you will converge quicker (dont have to wait for a full iteration of each example to adjust weights).

With more features to train on, convergence seems slower. To get to the same level, i take more epochs.
"""
callbacks_list = [checkpoint]
# %time err = model.fit(X_train, y_train, epochs=epoch, batch_size=500, verbose=0, callbacks=callbacks_list, validation_split=0.1)
# Out:
# Epoch 00001: val_mean_squared_error improved from inf to 0.32296, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00002: val_mean_squared_error improved from 0.32296 to 0.29310, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00003: val_mean_squared_error improved from 0.29310 to 0.24655, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00004: val_mean_squared_error improved from 0.24655 to 0.18106, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00005: val_mean_squared_error improved from 0.18106 to 0.11161, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00006: val_mean_squared_error improved from 0.11161 to 0.05846, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00007: val_mean_squared_error improved from 0.05846 to 0.02823, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00008: val_mean_squared_error improved from 0.02823 to 0.01668, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00009: val_mean_squared_error improved from 0.01668 to 0.01466, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00010: val_mean_squared_error did not improve
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 00012: val_mean_squared_error did not improve
# Epoch 00013: val_mean_squared_error improved from 0.01466 to 0.00930, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00014: val_mean_squared_error improved from 0.00930 to 0.00548, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 00016: val_mean_squared_error did not improve
# Epoch 00017: val_mean_squared_error did not improve
# Epoch 00018: val_mean_squared_error improved from 0.00548 to 0.00491, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00019: val_mean_squared_error improved from 0.00491 to 0.00194, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00020: val_mean_squared_error improved from 0.00194 to 0.00138, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00021: val_mean_squared_error improved from 0.00138 to 0.00131, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00022: val_mean_squared_error improved from 0.00131 to 0.00081, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00023: val_mean_squared_error improved from 0.00081 to 0.00054, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00024: val_mean_squared_error did not improve
# Epoch 00025: val_mean_squared_error improved from 0.00054 to 0.00025, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00026: val_mean_squared_error improved from 0.00025 to 0.00024, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 00028: val_mean_squared_error did not improve
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 00030: val_mean_squared_error improved from 0.00024 to 0.00018, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00031: val_mean_squared_error improved from 0.00018 to 0.00013, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00032: val_mean_squared_error did not improve
# Epoch 00033: val_mean_squared_error did not improve
# Epoch 00034: val_mean_squared_error did not improve
# Epoch 00035: val_mean_squared_error did not improve
# Epoch 00036: val_mean_squared_error did not improve
# Epoch 00037: val_mean_squared_error did not improve
# Epoch 00038: val_mean_squared_error did not improve
# Epoch 00039: val_mean_squared_error did not improve
# Epoch 00040: val_mean_squared_error did not improve
# Epoch 00041: val_mean_squared_error did not improve
# Epoch 00042: val_mean_squared_error did not improve
# Epoch 00043: val_mean_squared_error did not improve
# Epoch 00044: val_mean_squared_error did not improve
# Epoch 00045: val_mean_squared_error did not improve
# Epoch 00046: val_mean_squared_error did not improve
# Epoch 00047: val_mean_squared_error did not improve
# Epoch 00048: val_mean_squared_error did not improve
# Epoch 00049: val_mean_squared_error did not improve
# Epoch 00050: val_mean_squared_error did not improve
# Epoch 00051: val_mean_squared_error did not improve
# Epoch 00052: val_mean_squared_error did not improve
# Epoch 00053: val_mean_squared_error did not improve
# Epoch 00054: val_mean_squared_error improved from 0.00013 to 0.00013, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00055: val_mean_squared_error improved from 0.00013 to 0.00012, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00056: val_mean_squared_error did not improve
# Epoch 00057: val_mean_squared_error improved from 0.00012 to 0.00011, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00058: val_mean_squared_error did not improve
# Epoch 00059: val_mean_squared_error did not improve
# Epoch 00060: val_mean_squared_error did not improve
# Epoch 00061: val_mean_squared_error did not improve
# Epoch 00062: val_mean_squared_error did not improve
# Epoch 00063: val_mean_squared_error did not improve
# Epoch 00064: val_mean_squared_error did not improve
# Epoch 00065: val_mean_squared_error did not improve
# Epoch 00066: val_mean_squared_error did not improve
# Epoch 00067: val_mean_squared_error did not improve
# Epoch 00068: val_mean_squared_error did not improve
# Epoch 00069: val_mean_squared_error did not improve
# Epoch 00070: val_mean_squared_error did not improve
# Epoch 00071: val_mean_squared_error did not improve
# Epoch 00072: val_mean_squared_error did not improve
# Epoch 00073: val_mean_squared_error did not improve
# Epoch 00074: val_mean_squared_error did not improve
# Epoch 00075: val_mean_squared_error did not improve
# Epoch 00076: val_mean_squared_error did not improve
# Epoch 00077: val_mean_squared_error did not improve
# Epoch 00078: val_mean_squared_error did not improve
# Epoch 00079: val_mean_squared_error did not improve
# Epoch 00080: val_mean_squared_error did not improve
# Epoch 00081: val_mean_squared_error did not improve
# Epoch 00082: val_mean_squared_error did not improve
# Epoch 00083: val_mean_squared_error did not improve
# Epoch 00084: val_mean_squared_error did not improve
# Epoch 00085: val_mean_squared_error did not improve
# Epoch 00086: val_mean_squared_error did not improve
# Epoch 00087: val_mean_squared_error did not improve
# Epoch 00088: val_mean_squared_error did not improve
# Epoch 00089: val_mean_squared_error did not improve
# Epoch 00090: val_mean_squared_error improved from 0.00011 to 0.00011, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00091: val_mean_squared_error did not improve
# Epoch 00092: val_mean_squared_error did not improve
# Epoch 00093: val_mean_squared_error did not improve
# Epoch 00094: val_mean_squared_error improved from 0.00011 to 0.00010, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00095: val_mean_squared_error did not improve
# Epoch 00096: val_mean_squared_error did not improve
# Epoch 00097: val_mean_squared_error improved from 0.00010 to 0.00010, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00098: val_mean_squared_error did not improve
# Epoch 00099: val_mean_squared_error did not improve
# Epoch 00100: val_mean_squared_error did not improve
# Epoch 00101: val_mean_squared_error did not improve
# Epoch 00102: val_mean_squared_error did not improve
# Epoch 00103: val_mean_squared_error did not improve
# Epoch 00104: val_mean_squared_error did not improve
# Epoch 00105: val_mean_squared_error did not improve
# Epoch 00106: val_mean_squared_error did not improve
# Epoch 00107: val_mean_squared_error did not improve
# Epoch 00108: val_mean_squared_error did not improve
# Epoch 00109: val_mean_squared_error did not improve
# Epoch 00110: val_mean_squared_error did not improve
# Epoch 00111: val_mean_squared_error did not improve
# Epoch 00112: val_mean_squared_error did not improve
# Epoch 00113: val_mean_squared_error did not improve
# Epoch 00114: val_mean_squared_error did not improve
# Epoch 00115: val_mean_squared_error did not improve
# Epoch 00116: val_mean_squared_error improved from 0.00010 to 0.00008, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00117: val_mean_squared_error did not improve
# Epoch 00118: val_mean_squared_error did not improve
# Epoch 00119: val_mean_squared_error did not improve
# Epoch 00120: val_mean_squared_error did not improve
# Epoch 00121: val_mean_squared_error did not improve
# Epoch 00122: val_mean_squared_error did not improve
# Epoch 00123: val_mean_squared_error improved from 0.00008 to 0.00008, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00124: val_mean_squared_error did not improve
# Epoch 00125: val_mean_squared_error did not improve
# Epoch 00126: val_mean_squared_error did not improve
# Epoch 00127: val_mean_squared_error did not improve
# Epoch 00128: val_mean_squared_error did not improve
# Epoch 00129: val_mean_squared_error did not improve
# Epoch 00130: val_mean_squared_error did not improve
# Epoch 00131: val_mean_squared_error did not improve
# Epoch 00132: val_mean_squared_error did not improve
# Epoch 00133: val_mean_squared_error did not improve
# Epoch 00134: val_mean_squared_error did not improve
# Epoch 00135: val_mean_squared_error did not improve
# Epoch 00136: val_mean_squared_error did not improve
# Epoch 00137: val_mean_squared_error improved from 0.00008 to 0.00006, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00138: val_mean_squared_error did not improve
# Epoch 00139: val_mean_squared_error did not improve
# Epoch 00140: val_mean_squared_error did not improve
# Epoch 00141: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00142: val_mean_squared_error did not improve
# Epoch 00143: val_mean_squared_error did not improve
# Epoch 00144: val_mean_squared_error did not improve
# Epoch 00145: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00146: val_mean_squared_error did not improve
# Epoch 00147: val_mean_squared_error did not improve
# Epoch 00148: val_mean_squared_error did not improve
# Epoch 00149: val_mean_squared_error did not improve
# Epoch 00150: val_mean_squared_error did not improve
# Epoch 00151: val_mean_squared_error did not improve
# Epoch 00152: val_mean_squared_error did not improve
# Epoch 00153: val_mean_squared_error did not improve
# Epoch 00154: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00155: val_mean_squared_error did not improve
# Epoch 00156: val_mean_squared_error did not improve
# Epoch 00157: val_mean_squared_error did not improve
# Epoch 00158: val_mean_squared_error did not improve
# Epoch 00159: val_mean_squared_error did not improve
# Epoch 00160: val_mean_squared_error did not improve
# Epoch 00161: val_mean_squared_error improved from 0.00006 to 0.00005, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00162: val_mean_squared_error did not improve
# Epoch 00163: val_mean_squared_error did not improve
# Epoch 00164: val_mean_squared_error did not improve
# Epoch 00165: val_mean_squared_error did not improve
# Epoch 00166: val_mean_squared_error did not improve
# Epoch 00167: val_mean_squared_error did not improve
# Epoch 00168: val_mean_squared_error did not improve
# Epoch 00169: val_mean_squared_error did not improve
# Epoch 00170: val_mean_squared_error did not improve
# Epoch 00171: val_mean_squared_error did not improve
# Epoch 00172: val_mean_squared_error did not improve
# Epoch 00173: val_mean_squared_error did not improve
# Epoch 00174: val_mean_squared_error did not improve
# Epoch 00175: val_mean_squared_error improved from 0.00005 to 0.00005, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00176: val_mean_squared_error did not improve
# Epoch 00177: val_mean_squared_error did not improve
# Epoch 00178: val_mean_squared_error improved from 0.00005 to 0.00005, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00179: val_mean_squared_error did not improve
# Epoch 00180: val_mean_squared_error did not improve
# Epoch 00181: val_mean_squared_error did not improve
# Epoch 00182: val_mean_squared_error did not improve
# Epoch 00183: val_mean_squared_error did not improve
# Epoch 00184: val_mean_squared_error did not improve
# Epoch 00185: val_mean_squared_error did not improve
# Epoch 00186: val_mean_squared_error did not improve
# Epoch 00187: val_mean_squared_error did not improve
# Epoch 00188: val_mean_squared_error did not improve
# Epoch 00189: val_mean_squared_error did not improve
# Epoch 00190: val_mean_squared_error did not improve
# Epoch 00191: val_mean_squared_error did not improve
# Epoch 00192: val_mean_squared_error did not improve
# Epoch 00193: val_mean_squared_error did not improve
# Epoch 00194: val_mean_squared_error did not improve
# Epoch 00195: val_mean_squared_error did not improve
# Epoch 00196: val_mean_squared_error did not improve
# Epoch 00197: val_mean_squared_error did not improve
# Epoch 00198: val_mean_squared_error did not improve
# Epoch 00199: val_mean_squared_error did not improve
# Epoch 00200: val_mean_squared_error improved from 0.00005 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00201: val_mean_squared_error did not improve
# Epoch 00202: val_mean_squared_error did not improve
# Epoch 00203: val_mean_squared_error did not improve
# Epoch 00204: val_mean_squared_error did not improve
# Epoch 00205: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00206: val_mean_squared_error did not improve
# Epoch 00207: val_mean_squared_error did not improve
# Epoch 00208: val_mean_squared_error did not improve
# Epoch 00209: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00210: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00211: val_mean_squared_error did not improve
# Epoch 00212: val_mean_squared_error did not improve
# Epoch 00213: val_mean_squared_error did not improve
# Epoch 00214: val_mean_squared_error did not improve
# Epoch 00215: val_mean_squared_error did not improve
# Epoch 00216: val_mean_squared_error did not improve
# Epoch 00217: val_mean_squared_error did not improve
# Epoch 00218: val_mean_squared_error did not improve
# Epoch 00219: val_mean_squared_error did not improve
# Epoch 00220: val_mean_squared_error did not improve
# Epoch 00221: val_mean_squared_error did not improve
# Epoch 00222: val_mean_squared_error did not improve
# Epoch 00223: val_mean_squared_error did not improve
# Epoch 00224: val_mean_squared_error did not improve
# Epoch 00225: val_mean_squared_error did not improve
# Epoch 00226: val_mean_squared_error did not improve
# Epoch 00227: val_mean_squared_error did not improve
# Epoch 00228: val_mean_squared_error did not improve
# Epoch 00229: val_mean_squared_error did not improve
# Epoch 00230: val_mean_squared_error did not improve
# Epoch 00231: val_mean_squared_error did not improve
# Epoch 00232: val_mean_squared_error did not improve
# Epoch 00233: val_mean_squared_error did not improve
# Epoch 00234: val_mean_squared_error did not improve
# Epoch 00235: val_mean_squared_error did not improve
# Epoch 00236: val_mean_squared_error did not improve
# Epoch 00237: val_mean_squared_error did not improve
# Epoch 00238: val_mean_squared_error did not improve
# Epoch 00239: val_mean_squared_error did not improve
# Epoch 00240: val_mean_squared_error did not improve
# Epoch 00241: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00242: val_mean_squared_error did not improve
# Epoch 00243: val_mean_squared_error did not improve
# Epoch 00244: val_mean_squared_error did not improve
# Epoch 00245: val_mean_squared_error did not improve
# Epoch 00246: val_mean_squared_error did not improve
# Epoch 00247: val_mean_squared_error did not improve
# Epoch 00248: val_mean_squared_error did not improve
# Epoch 00249: val_mean_squared_error did not improve
# Epoch 00250: val_mean_squared_error did not improve
# Epoch 00251: val_mean_squared_error did not improve
# Epoch 00252: val_mean_squared_error did not improve
# Epoch 00253: val_mean_squared_error did not improve
# Epoch 00254: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00255: val_mean_squared_error did not improve
# Epoch 00256: val_mean_squared_error did not improve
# Epoch 00257: val_mean_squared_error did not improve
# Epoch 00258: val_mean_squared_error did not improve
# Epoch 00259: val_mean_squared_error did not improve
# Epoch 00260: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00261: val_mean_squared_error did not improve
# Epoch 00262: val_mean_squared_error did not improve
# Epoch 00263: val_mean_squared_error did not improve
# Epoch 00264: val_mean_squared_error did not improve
# Epoch 00265: val_mean_squared_error did not improve
# Epoch 00266: val_mean_squared_error did not improve
# Epoch 00267: val_mean_squared_error did not improve
# Epoch 00268: val_mean_squared_error did not improve
# Epoch 00269: val_mean_squared_error did not improve
# Epoch 00270: val_mean_squared_error did not improve
# Epoch 00271: val_mean_squared_error did not improve
# Epoch 00272: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00273: val_mean_squared_error did not improve
# Epoch 00274: val_mean_squared_error did not improve
# Epoch 00275: val_mean_squared_error did not improve
# Epoch 00276: val_mean_squared_error did not improve
# Epoch 00277: val_mean_squared_error did not improve
# Epoch 00278: val_mean_squared_error did not improve
# Epoch 00279: val_mean_squared_error did not improve
# Epoch 00280: val_mean_squared_error did not improve
# Epoch 00281: val_mean_squared_error did not improve
# Epoch 00282: val_mean_squared_error did not improve
# Epoch 00283: val_mean_squared_error did not improve
# Epoch 00284: val_mean_squared_error did not improve
# Epoch 00285: val_mean_squared_error did not improve
# Epoch 00286: val_mean_squared_error did not improve
# Epoch 00287: val_mean_squared_error did not improve
# Epoch 00288: val_mean_squared_error did not improve
# Epoch 00289: val_mean_squared_error did not improve
# Epoch 00290: val_mean_squared_error did not improve
# Epoch 00291: val_mean_squared_error did not improve
# Epoch 00292: val_mean_squared_error did not improve
# Epoch 00293: val_mean_squared_error did not improve
# Epoch 00294: val_mean_squared_error did not improve
# Epoch 00295: val_mean_squared_error did not improve
# Epoch 00296: val_mean_squared_error did not improve
# Epoch 00297: val_mean_squared_error did not improve
# Epoch 00298: val_mean_squared_error did not improve
# Epoch 00299: val_mean_squared_error did not improve
# Epoch 00300: val_mean_squared_error did not improve
# Epoch 00301: val_mean_squared_error did not improve
# Epoch 00302: val_mean_squared_error did not improve
# Epoch 00303: val_mean_squared_error did not improve
# Epoch 00304: val_mean_squared_error did not improve
# Epoch 00305: val_mean_squared_error did not improve
# Epoch 00306: val_mean_squared_error did not improve
# Epoch 00307: val_mean_squared_error did not improve
# Epoch 00308: val_mean_squared_error did not improve
# Epoch 00309: val_mean_squared_error did not improve
# Epoch 00310: val_mean_squared_error did not improve
# Epoch 00311: val_mean_squared_error did not improve
# Epoch 00312: val_mean_squared_error did not improve
# Epoch 00313: val_mean_squared_error did not improve
# Epoch 00314: val_mean_squared_error improved from 0.00004 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00315: val_mean_squared_error did not improve
# Epoch 00316: val_mean_squared_error did not improve
# Epoch 00317: val_mean_squared_error did not improve
# Epoch 00318: val_mean_squared_error did not improve
# Epoch 00319: val_mean_squared_error did not improve
# Epoch 00320: val_mean_squared_error did not improve
# Epoch 00321: val_mean_squared_error did not improve
# Epoch 00322: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00323: val_mean_squared_error did not improve
# Epoch 00324: val_mean_squared_error did not improve
# Epoch 00325: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00326: val_mean_squared_error did not improve
# Epoch 00327: val_mean_squared_error did not improve
# Epoch 00328: val_mean_squared_error did not improve
# Epoch 00329: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00330: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00331: val_mean_squared_error did not improve
# Epoch 00332: val_mean_squared_error did not improve
# Epoch 00333: val_mean_squared_error did not improve
# Epoch 00334: val_mean_squared_error did not improve
# Epoch 00335: val_mean_squared_error did not improve
# Epoch 00336: val_mean_squared_error did not improve
# Epoch 00337: val_mean_squared_error did not improve
# Epoch 00338: val_mean_squared_error did not improve
# Epoch 00339: val_mean_squared_error did not improve
# Epoch 00340: val_mean_squared_error did not improve
# Epoch 00341: val_mean_squared_error did not improve
# Epoch 00342: val_mean_squared_error did not improve
# Epoch 00343: val_mean_squared_error did not improve
# Epoch 00344: val_mean_squared_error did not improve
# Epoch 00345: val_mean_squared_error did not improve
# Epoch 00346: val_mean_squared_error did not improve
# Epoch 00347: val_mean_squared_error did not improve
# Epoch 00348: val_mean_squared_error did not improve
# Epoch 00349: val_mean_squared_error did not improve
# Epoch 00350: val_mean_squared_error did not improve
# Epoch 00351: val_mean_squared_error did not improve
# Epoch 00352: val_mean_squared_error did not improve
# Epoch 00353: val_mean_squared_error did not improve
# Epoch 00354: val_mean_squared_error did not improve
# Epoch 00355: val_mean_squared_error did not improve
# Epoch 00356: val_mean_squared_error did not improve
# Epoch 00357: val_mean_squared_error did not improve
# Epoch 00358: val_mean_squared_error did not improve
# Epoch 00359: val_mean_squared_error did not improve
# Epoch 00360: val_mean_squared_error did not improve
# Epoch 00361: val_mean_squared_error did not improve
# Epoch 00362: val_mean_squared_error did not improve
# Epoch 00363: val_mean_squared_error did not improve
# Epoch 00364: val_mean_squared_error did not improve
# Epoch 00365: val_mean_squared_error did not improve
# Epoch 00366: val_mean_squared_error did not improve
# Epoch 00367: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00368: val_mean_squared_error did not improve
# Epoch 00369: val_mean_squared_error did not improve
# Epoch 00370: val_mean_squared_error did not improve
# Epoch 00371: val_mean_squared_error did not improve
# Epoch 00372: val_mean_squared_error did not improve
# Epoch 00373: val_mean_squared_error did not improve
# Epoch 00374: val_mean_squared_error did not improve
# Epoch 00375: val_mean_squared_error did not improve
# Epoch 00376: val_mean_squared_error did not improve
# Epoch 00377: val_mean_squared_error did not improve
# Epoch 00378: val_mean_squared_error did not improve
# Epoch 00379: val_mean_squared_error did not improve
# Epoch 00380: val_mean_squared_error did not improve
# Epoch 00381: val_mean_squared_error did not improve
# Epoch 00382: val_mean_squared_error did not improve
# Epoch 00383: val_mean_squared_error did not improve
# Epoch 00384: val_mean_squared_error did not improve
# Epoch 00385: val_mean_squared_error did not improve
# Epoch 00386: val_mean_squared_error did not improve
# Epoch 00387: val_mean_squared_error did not improve
# Epoch 00388: val_mean_squared_error did not improve
# Epoch 00389: val_mean_squared_error did not improve
# Epoch 00390: val_mean_squared_error did not improve
# Epoch 00391: val_mean_squared_error did not improve
# Epoch 00392: val_mean_squared_error did not improve
# Epoch 00393: val_mean_squared_error did not improve
# Epoch 00394: val_mean_squared_error did not improve
# Epoch 00395: val_mean_squared_error did not improve
# Epoch 00396: val_mean_squared_error did not improve
# Epoch 00397: val_mean_squared_error did not improve
# Epoch 00398: val_mean_squared_error did not improve
# Epoch 00399: val_mean_squared_error did not improve
# Epoch 00400: val_mean_squared_error did not improve
# Epoch 00401: val_mean_squared_error did not improve
# Epoch 00402: val_mean_squared_error did not improve
# Epoch 00403: val_mean_squared_error did not improve
# Epoch 00404: val_mean_squared_error did not improve
# Epoch 00405: val_mean_squared_error did not improve
# Epoch 00406: val_mean_squared_error did not improve
# Epoch 00407: val_mean_squared_error did not improve
# Epoch 00408: val_mean_squared_error did not improve
# Epoch 00409: val_mean_squared_error did not improve
# Epoch 00410: val_mean_squared_error did not improve
# Epoch 00411: val_mean_squared_error did not improve
# Epoch 00412: val_mean_squared_error did not improve
# Epoch 00413: val_mean_squared_error did not improve
# Epoch 00414: val_mean_squared_error did not improve
# Epoch 00415: val_mean_squared_error did not improve
# Epoch 00416: val_mean_squared_error did not improve
# Epoch 00417: val_mean_squared_error did not improve
# Epoch 00418: val_mean_squared_error did not improve
# Epoch 00419: val_mean_squared_error did not improve
# Epoch 00420: val_mean_squared_error did not improve
# Epoch 00421: val_mean_squared_error did not improve
# Epoch 00422: val_mean_squared_error did not improve
# Epoch 00423: val_mean_squared_error did not improve
# Epoch 00424: val_mean_squared_error did not improve
# Epoch 00425: val_mean_squared_error did not improve
# Epoch 00426: val_mean_squared_error did not improve
# Epoch 00427: val_mean_squared_error did not improve
# Epoch 00428: val_mean_squared_error did not improve
# Epoch 00429: val_mean_squared_error did not improve
# Epoch 00430: val_mean_squared_error did not improve
# Epoch 00431: val_mean_squared_error did not improve
# Epoch 00432: val_mean_squared_error did not improve
# Epoch 00433: val_mean_squared_error did not improve
# Epoch 00434: val_mean_squared_error did not improve
# Epoch 00435: val_mean_squared_error did not improve
# Epoch 00436: val_mean_squared_error did not improve
# Epoch 00437: val_mean_squared_error did not improve
# Epoch 00438: val_mean_squared_error did not improve
# Epoch 00439: val_mean_squared_error did not improve
# Epoch 00440: val_mean_squared_error did not improve
# Epoch 00441: val_mean_squared_error did not improve
# Epoch 00442: val_mean_squared_error did not improve
# Epoch 00443: val_mean_squared_error did not improve
# Epoch 00444: val_mean_squared_error did not improve
# Epoch 00445: val_mean_squared_error did not improve
# Epoch 00446: val_mean_squared_error did not improve
# Epoch 00447: val_mean_squared_error did not improve
# Epoch 00448: val_mean_squared_error did not improve
# Epoch 00449: val_mean_squared_error did not improve
# Epoch 00450: val_mean_squared_error did not improve
# Epoch 00451: val_mean_squared_error did not improve
# Epoch 00452: val_mean_squared_error did not improve
# Epoch 00453: val_mean_squared_error did not improve
# Epoch 00454: val_mean_squared_error did not improve
# Epoch 00455: val_mean_squared_error did not improve
# Epoch 00456: val_mean_squared_error did not improve
# Epoch 00457: val_mean_squared_error did not improve
# Epoch 00458: val_mean_squared_error did not improve
# Epoch 00459: val_mean_squared_error did not improve
# Epoch 00460: val_mean_squared_error did not improve
# Epoch 00461: val_mean_squared_error did not improve
# Epoch 00462: val_mean_squared_error did not improve
# Epoch 00463: val_mean_squared_error did not improve
# Epoch 00464: val_mean_squared_error did not improve
# Epoch 00465: val_mean_squared_error did not improve
# Epoch 00466: val_mean_squared_error did not improve
# Epoch 00467: val_mean_squared_error did not improve
# Epoch 00468: val_mean_squared_error did not improve
# Epoch 00469: val_mean_squared_error did not improve
# Epoch 00470: val_mean_squared_error did not improve
# Epoch 00471: val_mean_squared_error did not improve
# Epoch 00472: val_mean_squared_error did not improve
# Epoch 00473: val_mean_squared_error did not improve
# Epoch 00474: val_mean_squared_error did not improve
# Epoch 00475: val_mean_squared_error did not improve
# Epoch 00476: val_mean_squared_error did not improve
# Epoch 00477: val_mean_squared_error did not improve
# Epoch 00478: val_mean_squared_error did not improve
# Epoch 00479: val_mean_squared_error did not improve
# Epoch 00480: val_mean_squared_error did not improve
# Epoch 00481: val_mean_squared_error did not improve
# Epoch 00482: val_mean_squared_error did not improve
# Epoch 00483: val_mean_squared_error did not improve
# Epoch 00484: val_mean_squared_error did not improve
# Epoch 00485: val_mean_squared_error did not improve
# Epoch 00486: val_mean_squared_error did not improve
# Epoch 00487: val_mean_squared_error did not improve
# Epoch 00488: val_mean_squared_error did not improve
# Epoch 00489: val_mean_squared_error did not improve
# Epoch 00490: val_mean_squared_error did not improve
# Epoch 00491: val_mean_squared_error did not improve
# Epoch 00492: val_mean_squared_error did not improve
# Epoch 00493: val_mean_squared_error did not improve
# Epoch 00494: val_mean_squared_error did not improve
# Epoch 00495: val_mean_squared_error did not improve
# Epoch 00496: val_mean_squared_error did not improve
# Epoch 00497: val_mean_squared_error did not improve
# Epoch 00498: val_mean_squared_error did not improve
# Epoch 00499: val_mean_squared_error did not improve
# Epoch 00500: val_mean_squared_error did not improve
# Epoch 00501: val_mean_squared_error did not improve
# Epoch 00502: val_mean_squared_error did not improve
# Epoch 00503: val_mean_squared_error did not improve
# Epoch 00504: val_mean_squared_error did not improve
# Epoch 00505: val_mean_squared_error did not improve
# Epoch 00506: val_mean_squared_error did not improve
# Epoch 00507: val_mean_squared_error did not improve
# Epoch 00508: val_mean_squared_error did not improve
# Epoch 00509: val_mean_squared_error did not improve
# Epoch 00510: val_mean_squared_error did not improve
# Epoch 00511: val_mean_squared_error did not improve
# Epoch 00512: val_mean_squared_error did not improve
# Epoch 00513: val_mean_squared_error did not improve
# Epoch 00514: val_mean_squared_error did not improve
# Epoch 00515: val_mean_squared_error did not improve
# Epoch 00516: val_mean_squared_error did not improve
# Epoch 00517: val_mean_squared_error did not improve
# Epoch 00518: val_mean_squared_error did not improve
# Epoch 00519: val_mean_squared_error did not improve
# Epoch 00520: val_mean_squared_error did not improve
# Epoch 00521: val_mean_squared_error did not improve
# Epoch 00522: val_mean_squared_error did not improve
# Epoch 00523: val_mean_squared_error did not improve
# Epoch 00524: val_mean_squared_error did not improve
# Epoch 00525: val_mean_squared_error did not improve
# Epoch 00526: val_mean_squared_error did not improve
# Epoch 00527: val_mean_squared_error did not improve
# Epoch 00528: val_mean_squared_error did not improve
# Epoch 00529: val_mean_squared_error did not improve
# Epoch 00530: val_mean_squared_error did not improve
# Epoch 00531: val_mean_squared_error did not improve
# Epoch 00532: val_mean_squared_error did not improve
# Epoch 00533: val_mean_squared_error did not improve
# Epoch 00534: val_mean_squared_error did not improve
# Epoch 00535: val_mean_squared_error did not improve
# Epoch 00536: val_mean_squared_error did not improve
# Epoch 00537: val_mean_squared_error did not improve
# Epoch 00538: val_mean_squared_error did not improve
# Epoch 00539: val_mean_squared_error did not improve
# Epoch 00540: val_mean_squared_error did not improve
# Epoch 00541: val_mean_squared_error did not improve
# Epoch 00542: val_mean_squared_error did not improve
# Epoch 00543: val_mean_squared_error did not improve
# Epoch 00544: val_mean_squared_error did not improve
# Epoch 00545: val_mean_squared_error did not improve
# Epoch 00546: val_mean_squared_error did not improve
# Epoch 00547: val_mean_squared_error did not improve
# Epoch 00548: val_mean_squared_error did not improve
# Epoch 00549: val_mean_squared_error did not improve
# Epoch 00550: val_mean_squared_error did not improve
# Epoch 00551: val_mean_squared_error did not improve
# Epoch 00552: val_mean_squared_error did not improve
# Epoch 00553: val_mean_squared_error did not improve
# Epoch 00554: val_mean_squared_error did not improve
# Epoch 00555: val_mean_squared_error did not improve
# Epoch 00556: val_mean_squared_error did not improve
# Epoch 00557: val_mean_squared_error did not improve
# Epoch 00558: val_mean_squared_error did not improve
# Epoch 00559: val_mean_squared_error did not improve
# Epoch 00560: val_mean_squared_error did not improve
# Epoch 00561: val_mean_squared_error did not improve
# Epoch 00562: val_mean_squared_error did not improve
# Epoch 00563: val_mean_squared_error did not improve
# Epoch 00564: val_mean_squared_error did not improve
# Epoch 00565: val_mean_squared_error did not improve
# Epoch 00566: val_mean_squared_error did not improve
# Epoch 00567: val_mean_squared_error did not improve
# Epoch 00568: val_mean_squared_error did not improve
# Epoch 00569: val_mean_squared_error did not improve
# Epoch 00570: val_mean_squared_error did not improve
# Epoch 00571: val_mean_squared_error did not improve
# Epoch 00572: val_mean_squared_error did not improve
# Epoch 00573: val_mean_squared_error did not improve
# Epoch 00574: val_mean_squared_error did not improve
# Epoch 00575: val_mean_squared_error did not improve
# Epoch 00576: val_mean_squared_error did not improve
# Epoch 00577: val_mean_squared_error did not improve
# Epoch 00578: val_mean_squared_error did not improve
# Epoch 00579: val_mean_squared_error did not improve
# Epoch 00580: val_mean_squared_error did not improve
# Epoch 00581: val_mean_squared_error did not improve
# Epoch 00582: val_mean_squared_error did not improve
# Epoch 00583: val_mean_squared_error did not improve
# Epoch 00584: val_mean_squared_error did not improve
# Epoch 00585: val_mean_squared_error did not improve
# Epoch 00586: val_mean_squared_error did not improve
# Epoch 00587: val_mean_squared_error did not improve
# Epoch 00588: val_mean_squared_error did not improve
# Epoch 00589: val_mean_squared_error did not improve
# Epoch 00590: val_mean_squared_error did not improve
# Epoch 00591: val_mean_squared_error did not improve
# Epoch 00592: val_mean_squared_error did not improve
# Epoch 00593: val_mean_squared_error did not improve
# Epoch 00594: val_mean_squared_error did not improve
# Epoch 00595: val_mean_squared_error did not improve
# Epoch 00596: val_mean_squared_error did not improve
# Epoch 00597: val_mean_squared_error did not improve
# Epoch 00598: val_mean_squared_error did not improve
# Epoch 00599: val_mean_squared_error did not improve
# Epoch 00600: val_mean_squared_error did not improve
# Epoch 00601: val_mean_squared_error did not improve
# Epoch 00602: val_mean_squared_error did not improve
# Epoch 00603: val_mean_squared_error did not improve
# Epoch 00604: val_mean_squared_error did not improve
# Epoch 00605: val_mean_squared_error did not improve
# Epoch 00606: val_mean_squared_error did not improve
# Epoch 00607: val_mean_squared_error did not improve
# Epoch 00608: val_mean_squared_error did not improve
# Epoch 00609: val_mean_squared_error did not improve
# Epoch 00610: val_mean_squared_error did not improve
# Epoch 00611: val_mean_squared_error did not improve
# Epoch 00612: val_mean_squared_error did not improve
# Epoch 00613: val_mean_squared_error did not improve
# Epoch 00614: val_mean_squared_error did not improve
# Epoch 00615: val_mean_squared_error did not improve
# Epoch 00616: val_mean_squared_error did not improve
# Epoch 00617: val_mean_squared_error did not improve
# Epoch 00618: val_mean_squared_error did not improve
# Epoch 00619: val_mean_squared_error did not improve
# Epoch 00620: val_mean_squared_error did not improve
# Epoch 00621: val_mean_squared_error did not improve
# Epoch 00622: val_mean_squared_error did not improve
# Epoch 00623: val_mean_squared_error did not improve
# Epoch 00624: val_mean_squared_error did not improve
# Epoch 00625: val_mean_squared_error did not improve
# Epoch 00626: val_mean_squared_error did not improve
# Epoch 00627: val_mean_squared_error did not improve
# Epoch 00628: val_mean_squared_error did not improve
# Epoch 00629: val_mean_squared_error did not improve
# Epoch 00630: val_mean_squared_error did not improve
# Epoch 00631: val_mean_squared_error did not improve
# Epoch 00632: val_mean_squared_error did not improve
# Epoch 00633: val_mean_squared_error did not improve
# Epoch 00634: val_mean_squared_error did not improve
# Epoch 00635: val_mean_squared_error did not improve
# Epoch 00636: val_mean_squared_error did not improve
# Epoch 00637: val_mean_squared_error did not improve
# Epoch 00638: val_mean_squared_error did not improve
# Epoch 00639: val_mean_squared_error did not improve
# Epoch 00640: val_mean_squared_error did not improve
# Epoch 00641: val_mean_squared_error did not improve
# Epoch 00642: val_mean_squared_error did not improve
# Epoch 00643: val_mean_squared_error did not improve
# Epoch 00644: val_mean_squared_error did not improve
# Epoch 00645: val_mean_squared_error did not improve
# Epoch 00646: val_mean_squared_error did not improve
# Epoch 00647: val_mean_squared_error did not improve
# Epoch 00648: val_mean_squared_error did not improve
# Epoch 00649: val_mean_squared_error did not improve
# Epoch 00650: val_mean_squared_error did not improve
# Epoch 00651: val_mean_squared_error did not improve
# Epoch 00652: val_mean_squared_error did not improve
# Epoch 00653: val_mean_squared_error did not improve
# Epoch 00654: val_mean_squared_error did not improve
# Epoch 00655: val_mean_squared_error did not improve
# Epoch 00656: val_mean_squared_error did not improve
# Epoch 00657: val_mean_squared_error did not improve
# Epoch 00658: val_mean_squared_error did not improve
# Epoch 00659: val_mean_squared_error did not improve
# Epoch 00660: val_mean_squared_error did not improve
# Epoch 00661: val_mean_squared_error did not improve
# Epoch 00662: val_mean_squared_error did not improve
# Epoch 00663: val_mean_squared_error did not improve
# Epoch 00664: val_mean_squared_error did not improve
# Epoch 00665: val_mean_squared_error did not improve
# Epoch 00666: val_mean_squared_error did not improve
# Epoch 00667: val_mean_squared_error did not improve
# Epoch 00668: val_mean_squared_error did not improve
# Epoch 00669: val_mean_squared_error did not improve
# Epoch 00670: val_mean_squared_error did not improve
# Epoch 00671: val_mean_squared_error did not improve
# Epoch 00672: val_mean_squared_error did not improve
# Epoch 00673: val_mean_squared_error did not improve
# Epoch 00674: val_mean_squared_error did not improve
# Epoch 00675: val_mean_squared_error did not improve
# Epoch 00676: val_mean_squared_error did not improve
# Epoch 00677: val_mean_squared_error did not improve
# Epoch 00678: val_mean_squared_error did not improve
# Epoch 00679: val_mean_squared_error did not improve
# Epoch 00680: val_mean_squared_error did not improve
# Epoch 00681: val_mean_squared_error did not improve
# Epoch 00682: val_mean_squared_error did not improve
# Epoch 00683: val_mean_squared_error did not improve
# Epoch 00684: val_mean_squared_error did not improve
# Epoch 00685: val_mean_squared_error did not improve
# Epoch 00686: val_mean_squared_error did not improve
# Epoch 00687: val_mean_squared_error did not improve
# Epoch 00688: val_mean_squared_error did not improve
# Epoch 00689: val_mean_squared_error did not improve
# Epoch 00690: val_mean_squared_error did not improve
# Epoch 00691: val_mean_squared_error did not improve
# Epoch 00692: val_mean_squared_error did not improve
# Epoch 00693: val_mean_squared_error did not improve
# Epoch 00694: val_mean_squared_error did not improve
# Epoch 00695: val_mean_squared_error did not improve
# Epoch 00696: val_mean_squared_error did not improve
# Epoch 00697: val_mean_squared_error did not improve
# Epoch 00698: val_mean_squared_error did not improve
# Epoch 00699: val_mean_squared_error did not improve
# Epoch 00700: val_mean_squared_error did not improve
# Epoch 00701: val_mean_squared_error did not improve
# Epoch 00702: val_mean_squared_error did not improve
# Epoch 00703: val_mean_squared_error did not improve
# Epoch 00704: val_mean_squared_error did not improve
# Epoch 00705: val_mean_squared_error did not improve
# Epoch 00706: val_mean_squared_error did not improve
# Epoch 00707: val_mean_squared_error did not improve
# Epoch 00708: val_mean_squared_error did not improve
# Epoch 00709: val_mean_squared_error did not improve
# Epoch 00710: val_mean_squared_error did not improve
# Epoch 00711: val_mean_squared_error did not improve
# Epoch 00712: val_mean_squared_error did not improve
# Epoch 00713: val_mean_squared_error did not improve
# Epoch 00714: val_mean_squared_error did not improve
# Epoch 00715: val_mean_squared_error did not improve
# Epoch 00716: val_mean_squared_error did not improve
# Epoch 00717: val_mean_squared_error did not improve
# Epoch 00718: val_mean_squared_error did not improve
# Epoch 00719: val_mean_squared_error did not improve
# Epoch 00720: val_mean_squared_error did not improve
# Epoch 00721: val_mean_squared_error did not improve
# Epoch 00722: val_mean_squared_error did not improve
# Epoch 00723: val_mean_squared_error did not improve
# Epoch 00724: val_mean_squared_error did not improve
# Epoch 00725: val_mean_squared_error did not improve
# Epoch 00726: val_mean_squared_error did not improve
# Epoch 00727: val_mean_squared_error did not improve
# Epoch 00728: val_mean_squared_error did not improve
# Epoch 00729: val_mean_squared_error did not improve
# Epoch 00730: val_mean_squared_error did not improve
# Epoch 00731: val_mean_squared_error did not improve
# Epoch 00732: val_mean_squared_error did not improve
# Epoch 00733: val_mean_squared_error did not improve
# Epoch 00734: val_mean_squared_error did not improve
# Epoch 00735: val_mean_squared_error did not improve
# Epoch 00736: val_mean_squared_error did not improve
# Epoch 00737: val_mean_squared_error did not improve
# Epoch 00738: val_mean_squared_error did not improve
# Epoch 00739: val_mean_squared_error did not improve
# Epoch 00740: val_mean_squared_error did not improve
# Epoch 00741: val_mean_squared_error did not improve
# Epoch 00742: val_mean_squared_error did not improve
# Epoch 00743: val_mean_squared_error did not improve
# Epoch 00744: val_mean_squared_error did not improve
# Epoch 00745: val_mean_squared_error did not improve
# Epoch 00746: val_mean_squared_error did not improve
# Epoch 00747: val_mean_squared_error did not improve
# Epoch 00748: val_mean_squared_error did not improve
# Epoch 00749: val_mean_squared_error did not improve
# Epoch 00750: val_mean_squared_error did not improve
# Epoch 00751: val_mean_squared_error did not improve
# Epoch 00752: val_mean_squared_error did not improve
# Epoch 00753: val_mean_squared_error did not improve
# Epoch 00754: val_mean_squared_error did not improve
# Epoch 00755: val_mean_squared_error did not improve
# Epoch 00756: val_mean_squared_error did not improve
# Epoch 00757: val_mean_squared_error did not improve
# Epoch 00758: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.weights.best.hdf5
# Epoch 00759: val_mean_squared_error did not improve
# Epoch 00760: val_mean_squared_error did not improve
# Epoch 00761: val_mean_squared_error did not improve
# Epoch 00762: val_mean_squared_error did not improve
# Epoch 00763: val_mean_squared_error did not improve
# Epoch 00764: val_mean_squared_error did not improve
# Epoch 00765: val_mean_squared_error did not improve
# Epoch 00766: val_mean_squared_error did not improve
# Epoch 00767: val_mean_squared_error did not improve
# Epoch 00768: val_mean_squared_error did not improve
# Epoch 00769: val_mean_squared_error did not improve
# Epoch 00770: val_mean_squared_error did not improve
# Epoch 00771: val_mean_squared_error did not improve
# Epoch 00772: val_mean_squared_error did not improve
# Epoch 00773: val_mean_squared_error did not improve
# Epoch 00774: val_mean_squared_error did not improve
# Epoch 00775: val_mean_squared_error did not improve
# Epoch 00776: val_mean_squared_error did not improve
# Epoch 00777: val_mean_squared_error did not improve
# Epoch 00778: val_mean_squared_error did not improve
# Epoch 00779: val_mean_squared_error did not improve
# Epoch 00780: val_mean_squared_error did not improve
# Epoch 00781: val_mean_squared_error did not improve
# Epoch 00782: val_mean_squared_error did not improve
# Epoch 00783: val_mean_squared_error did not improve
# Epoch 00784: val_mean_squared_error did not improve
# Epoch 00785: val_mean_squared_error did not improve
# Epoch 00786: val_mean_squared_error did not improve
# Epoch 00787: val_mean_squared_error did not improve
# Epoch 00788: val_mean_squared_error did not improve
# Epoch 00789: val_mean_squared_error did not improve
# Epoch 00790: val_mean_squared_error did not improve
# Epoch 00791: val_mean_squared_error did not improve
# Epoch 00792: val_mean_squared_error did not improve
# Epoch 00793: val_mean_squared_error did not improve
# Epoch 00794: val_mean_squared_error did not improve
# Epoch 00795: val_mean_squared_error did not improve
# Epoch 00796: val_mean_squared_error did not improve
# Epoch 00797: val_mean_squared_error did not improve
# Epoch 00798: val_mean_squared_error did not improve
# Epoch 00799: val_mean_squared_error did not improve
# Epoch 00800: val_mean_squared_error did not improve
# Epoch 00801: val_mean_squared_error did not improve
# Epoch 00802: val_mean_squared_error did not improve
# Epoch 00803: val_mean_squared_error did not improve
# Epoch 00804: val_mean_squared_error did not improve
# Epoch 00805: val_mean_squared_error did not improve
# Epoch 00806: val_mean_squared_error did not improve
# Epoch 00807: val_mean_squared_error did not improve
# Epoch 00808: val_mean_squared_error did not improve
# Epoch 00809: val_mean_squared_error did not improve
# Epoch 00810: val_mean_squared_error did not improve
# Epoch 00811: val_mean_squared_error did not improve
# Epoch 00812: val_mean_squared_error did not improve
# Epoch 00813: val_mean_squared_error did not improve
# Epoch 00814: val_mean_squared_error did not improve
# Epoch 00815: val_mean_squared_error did not improve
# Epoch 00816: val_mean_squared_error did not improve
# Epoch 00817: val_mean_squared_error did not improve
# Epoch 00818: val_mean_squared_error did not improve
# Epoch 00819: val_mean_squared_error did not improve
# Epoch 00820: val_mean_squared_error did not improve
# Epoch 00821: val_mean_squared_error did not improve
# Epoch 00822: val_mean_squared_error did not improve
# Epoch 00823: val_mean_squared_error did not improve
# Epoch 00824: val_mean_squared_error did not improve
# Epoch 00825: val_mean_squared_error did not improve
# Epoch 00826: val_mean_squared_error did not improve
# Epoch 00827: val_mean_squared_error did not improve
# Epoch 00828: val_mean_squared_error did not improve
# Epoch 00829: val_mean_squared_error did not improve
# Epoch 00830: val_mean_squared_error did not improve
# Epoch 00831: val_mean_squared_error did not improve
# Epoch 00832: val_mean_squared_error did not improve
# Epoch 00833: val_mean_squared_error did not improve
# Epoch 00834: val_mean_squared_error did not improve
# Epoch 00835: val_mean_squared_error did not improve
# Epoch 00836: val_mean_squared_error did not improve
# Epoch 00837: val_mean_squared_error did not improve
# Epoch 00838: val_mean_squared_error did not improve
# Epoch 00839: val_mean_squared_error did not improve
# Epoch 00840: val_mean_squared_error did not improve
# Epoch 00841: val_mean_squared_error did not improve
# Epoch 00842: val_mean_squared_error did not improve
# Epoch 00843: val_mean_squared_error did not improve
# Epoch 00844: val_mean_squared_error did not improve
# Epoch 00845: val_mean_squared_error did not improve
# Epoch 00846: val_mean_squared_error did not improve
# Epoch 00847: val_mean_squared_error did not improve
# Epoch 00848: val_mean_squared_error did not improve
# Epoch 00849: val_mean_squared_error did not improve
# Epoch 00850: val_mean_squared_error did not improve
# Epoch 00851: val_mean_squared_error did not improve
# Epoch 00852: val_mean_squared_error did not improve
# Epoch 00853: val_mean_squared_error did not improve
# Epoch 00854: val_mean_squared_error did not improve
# Epoch 00855: val_mean_squared_error did not improve
# Epoch 00856: val_mean_squared_error did not improve
# Epoch 00857: val_mean_squared_error did not improve
# Epoch 00858: val_mean_squared_error did not improve
# Epoch 00859: val_mean_squared_error did not improve
# Epoch 00860: val_mean_squared_error did not improve
# Epoch 00861: val_mean_squared_error did not improve
# Epoch 00862: val_mean_squared_error did not improve
# Epoch 00863: val_mean_squared_error did not improve
# Epoch 00864: val_mean_squared_error did not improve
# Epoch 00865: val_mean_squared_error did not improve
# Epoch 00866: val_mean_squared_error did not improve
# Epoch 00867: val_mean_squared_error did not improve
# Epoch 00868: val_mean_squared_error did not improve
# Epoch 00869: val_mean_squared_error did not improve
# Epoch 00870: val_mean_squared_error did not improve
# Epoch 00871: val_mean_squared_error did not improve
# Epoch 00872: val_mean_squared_error did not improve
# Epoch 00873: val_mean_squared_error did not improve
# Epoch 00874: val_mean_squared_error did not improve
# Epoch 00875: val_mean_squared_error did not improve
# Epoch 00876: val_mean_squared_error did not improve
# Epoch 00877: val_mean_squared_error did not improve
# Epoch 00878: val_mean_squared_error did not improve
# Epoch 00879: val_mean_squared_error did not improve
# Epoch 00880: val_mean_squared_error did not improve
# Epoch 00881: val_mean_squared_error did not improve
# Epoch 00882: val_mean_squared_error did not improve
# Epoch 00883: val_mean_squared_error did not improve
# Epoch 00884: val_mean_squared_error did not improve
# Epoch 00885: val_mean_squared_error did not improve
# Epoch 00886: val_mean_squared_error did not improve
# Epoch 00887: val_mean_squared_error did not improve
# Epoch 00888: val_mean_squared_error did not improve
# Epoch 00889: val_mean_squared_error did not improve
# Epoch 00890: val_mean_squared_error did not improve
# Epoch 00891: val_mean_squared_error did not improve
# Epoch 00892: val_mean_squared_error did not improve
# Epoch 00893: val_mean_squared_error did not improve
# Epoch 00894: val_mean_squared_error did not improve
# Epoch 00895: val_mean_squared_error did not improve
# Epoch 00896: val_mean_squared_error did not improve
# Epoch 00897: val_mean_squared_error did not improve
# Epoch 00898: val_mean_squared_error did not improve
# Epoch 00899: val_mean_squared_error did not improve
# Epoch 00900: val_mean_squared_error did not improve
# Epoch 00901: val_mean_squared_error did not improve
# Epoch 00902: val_mean_squared_error did not improve
# Epoch 00903: val_mean_squared_error did not improve
# Epoch 00904: val_mean_squared_error did not improve
# Epoch 00905: val_mean_squared_error did not improve
# Epoch 00906: val_mean_squared_error did not improve
# Epoch 00907: val_mean_squared_error did not improve
# Epoch 00908: val_mean_squared_error did not improve
# Epoch 00909: val_mean_squared_error did not improve
# Epoch 00910: val_mean_squared_error did not improve
# Epoch 00911: val_mean_squared_error did not improve
# Epoch 00912: val_mean_squared_error did not improve
# Epoch 00913: val_mean_squared_error did not improve
# Epoch 00914: val_mean_squared_error did not improve
# Epoch 00915: val_mean_squared_error did not improve
# Epoch 00916: val_mean_squared_error did not improve
# Epoch 00917: val_mean_squared_error did not improve
# Epoch 00918: val_mean_squared_error did not improve
# Epoch 00919: val_mean_squared_error did not improve
# Epoch 00920: val_mean_squared_error did not improve
# Epoch 00921: val_mean_squared_error did not improve
# Epoch 00922: val_mean_squared_error did not improve
# Epoch 00923: val_mean_squared_error did not improve
# Epoch 00924: val_mean_squared_error did not improve
# Epoch 00925: val_mean_squared_error did not improve
# Epoch 00926: val_mean_squared_error did not improve
# Epoch 00927: val_mean_squared_error did not improve
# Epoch 00928: val_mean_squared_error did not improve
# Epoch 00929: val_mean_squared_error did not improve
# Epoch 00930: val_mean_squared_error did not improve
# Epoch 00931: val_mean_squared_error did not improve
# Epoch 00932: val_mean_squared_error did not improve
# Epoch 00933: val_mean_squared_error did not improve
# Epoch 00934: val_mean_squared_error did not improve
# Epoch 00935: val_mean_squared_error did not improve
# Epoch 00936: val_mean_squared_error did not improve
# Epoch 00937: val_mean_squared_error did not improve
# Epoch 00938: val_mean_squared_error did not improve
# Epoch 00939: val_mean_squared_error did not improve
# Epoch 00940: val_mean_squared_error did not improve
# Epoch 00941: val_mean_squared_error did not improve
# Epoch 00942: val_mean_squared_error did not improve
# Epoch 00943: val_mean_squared_error did not improve
# Epoch 00944: val_mean_squared_error did not improve
# Epoch 00945: val_mean_squared_error did not improve
# Epoch 00946: val_mean_squared_error did not improve
# Epoch 00947: val_mean_squared_error did not improve
# Epoch 00948: val_mean_squared_error did not improve
# Epoch 00949: val_mean_squared_error did not improve
# Epoch 00950: val_mean_squared_error did not improve
# Epoch 00951: val_mean_squared_error did not improve
# Epoch 00952: val_mean_squared_error did not improve
# Epoch 00953: val_mean_squared_error did not improve
# Epoch 00954: val_mean_squared_error did not improve
# Epoch 00955: val_mean_squared_error did not improve
# Epoch 00956: val_mean_squared_error did not improve
# Epoch 00957: val_mean_squared_error did not improve
# Epoch 00958: val_mean_squared_error did not improve
# Epoch 00959: val_mean_squared_error did not improve
# Epoch 00960: val_mean_squared_error did not improve
# Epoch 00961: val_mean_squared_error did not improve
# Epoch 00962: val_mean_squared_error did not improve
# Epoch 00963: val_mean_squared_error did not improve
# Epoch 00964: val_mean_squared_error did not improve
# Epoch 00965: val_mean_squared_error did not improve
# Epoch 00966: val_mean_squared_error did not improve
# Epoch 00967: val_mean_squared_error did not improve
# Epoch 00968: val_mean_squared_error did not improve
# Epoch 00969: val_mean_squared_error did not improve
# Epoch 00970: val_mean_squared_error did not improve
# Epoch 00971: val_mean_squared_error did not improve
# Epoch 00972: val_mean_squared_error did not improve
# Epoch 00973: val_mean_squared_error did not improve
# Epoch 00974: val_mean_squared_error did not improve
# Epoch 00975: val_mean_squared_error did not improve
# Epoch 00976: val_mean_squared_error did not improve
# Epoch 00977: val_mean_squared_error did not improve
# Epoch 00978: val_mean_squared_error did not improve
# Epoch 00979: val_mean_squared_error did not improve
# Epoch 00980: val_mean_squared_error did not improve
# Epoch 00981: val_mean_squared_error did not improve
# Epoch 00982: val_mean_squared_error did not improve
# Epoch 00983: val_mean_squared_error did not improve
# Epoch 00984: val_mean_squared_error did not improve
# Epoch 00985: val_mean_squared_error did not improve
# Epoch 00986: val_mean_squared_error did not improve
# Epoch 00987: val_mean_squared_error did not improve
# Epoch 00988: val_mean_squared_error did not improve
# Epoch 00989: val_mean_squared_error did not improve
# Epoch 00990: val_mean_squared_error did not improve
# Epoch 00991: val_mean_squared_error did not improve
# Epoch 00992: val_mean_squared_error did not improve
# Epoch 00993: val_mean_squared_error did not improve
# Epoch 00994: val_mean_squared_error did not improve
# Epoch 00995: val_mean_squared_error did not improve
# Epoch 00996: val_mean_squared_error did not improve
# Epoch 00997: val_mean_squared_error did not improve
# Epoch 00998: val_mean_squared_error did not improve
# Epoch 00999: val_mean_squared_error did not improve
# Epoch 01000: val_mean_squared_error did not improve
# Wall time: 5min 56s

# %%
dill.dump(err.history, open("model weights/"+simname+"_first_err.dat", 'wb'))

# %% [markdown]
# ## Check testing errors
# - it converges to a low number very fast - how can i get more detail
# - but if i split using cross val split with random state, it takes ages to converge. Maybe i should only allow training on the past, as the model will always be used to predict the future. So training on random parts of the timeseries to predict other random parts might destroy historical trends that influence the future, and can be learned by the model.
# - train it on directional error for more useful results. Need y_train - X_train[:,idx_close_bid] as feature and evaluate against y_true - X_train[:,idx_close_bid]
# - it seems the model always predicts negative, so column zero
# - its easier to optimise over mse than mae, because values bigger and would decline more, so better gradients.
#
# Issues:
# - cannot checkpoint custom error functions
# - cannot write custom error functions
# - cannot debug custom error functions

# %%
err_history = dill.load(open("model weights/"+simname+"_first_err.dat", 'rb'))

# %%
#pd.DataFrame(model.predict(X_train))
if runLSTMBinary:
    print(pd.DataFrame(y_train).sum()) # classes are quite balanced
    pd.DataFrame(err_history)

# %%
print("smallest validation MAE: ", min(err_history['val_mean_absolute_error']))
print("smallest validation MSE: ", min(err_history['val_mean_squared_error']))
# Out:
# smallest validation MAE:  0.00388927032374
# smallest validation MSE:  3.37022721573e-05

# %%
for error_metric in list(err_history.keys()):
    if 'val' not in error_metric:
        plt.figure(figsize=(40,10))
        plt.plot(err_history[error_metric])
        plt.plot(err_history['val_' + error_metric])
        plt.title(error_metric, fontsize=30)
        plt.ylabel(error_metric)
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left', fontsize=30)
        plt.show()

# %% [markdown]
# ## Rerun LSTM with decaying learning rate:
#
# As seen from the above, the model seems to have converged nicely, but the mean absolute error on the development data remains at ~0.003X which means the model is unusable in practice. Ideally, we want to get ~0.0005. Let's go back to the best weight, and decay the learning rate while retraining the model
#
# We need this to get inside the average bid offer spread for EUR/USD, so 1.10115 - 1.10110. But lets not forget the data is scaled. Maybe it looks better when we unscale it.

# %%
# tune model by starting from best weights and rerunning with decaying learning rate
# Load the weight that worked the best
model.load_weights("model weights/"+simname+".weights.best.hdf5")
# create a new checkpoint to save improved weights under different name

checkpoint = ModelCheckpoint("model weights/"+simname + ".better_weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='min')
#epoch=60

# Train again with decaying learning rate
from keras.callbacks import LearningRateScheduler
import keras.backend as K

def scheduler(epoch):
    if epoch%2==0 and epoch!=0:
        lr = K.get_value(model.optimizer.lr)
        K.set_value(model.optimizer.lr, lr*.9)
        print("lr changed to {}".format(lr*.9))
    return K.get_value(model.optimizer.lr)
lr_decay = LearningRateScheduler(scheduler) # do sth to learning rate

callbacks_list = [checkpoint, lr_decay] # checkin with these once in a while
err_decay_lr = model.fit(X_train, y_train, epochs=int(epoch/3), batch_size=500, verbose=0, callbacks=callbacks_list, validation_split=0.1)
# Out:
# Epoch 00001: val_mean_squared_error improved from inf to 0.00006, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# Epoch 00002: val_mean_squared_error improved from 0.00006 to 0.00005, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# lr changed to 0.0009000000427477062
# Epoch 00003: val_mean_squared_error did not improve
# Epoch 00004: val_mean_squared_error improved from 0.00005 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# lr changed to 0.0008100000384729356
# Epoch 00005: val_mean_squared_error did not improve
# Epoch 00006: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# lr changed to 0.0007290000503417104
# Epoch 00007: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# Epoch 00008: val_mean_squared_error did not improve
# lr changed to 0.0006561000715009868
# Epoch 00009: val_mean_squared_error did not improve
# Epoch 00010: val_mean_squared_error did not improve
# lr changed to 0.0005904900433961303
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 00012: val_mean_squared_error improved from 0.00004 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# lr changed to 0.0005314410547725857
# Epoch 00013: val_mean_squared_error did not improve
# Epoch 00014: val_mean_squared_error did not improve
# lr changed to 0.00047829695977270604
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 00016: val_mean_squared_error did not improve
# lr changed to 0.0004304672533180565
# Epoch 00017: val_mean_squared_error did not improve
# Epoch 00018: val_mean_squared_error did not improve
# lr changed to 0.00038742052274756136
# Epoch 00019: val_mean_squared_error did not improve
# Epoch 00020: val_mean_squared_error did not improve
# lr changed to 0.0003486784757114947
# Epoch 00021: val_mean_squared_error did not improve
# Epoch 00022: val_mean_squared_error did not improve
# lr changed to 0.00031381062290165574
# Epoch 00023: val_mean_squared_error did not improve
# Epoch 00024: val_mean_squared_error did not improve
# lr changed to 0.0002824295632308349
# Epoch 00025: val_mean_squared_error did not improve
# Epoch 00026: val_mean_squared_error did not improve
# lr changed to 0.00025418660952709616
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 00028: val_mean_squared_error did not improve
# lr changed to 0.00022876793809700757
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 00030: val_mean_squared_error did not improve
# lr changed to 0.00020589114428730683
# Epoch 00031: val_mean_squared_error did not improve
# Epoch 00032: val_mean_squared_error did not improve
# lr changed to 0.00018530203378759326
# Epoch 00033: val_mean_squared_error did not improve
# Epoch 00034: val_mean_squared_error did not improve
# lr changed to 0.00016677183302817866
# Epoch 00035: val_mean_squared_error did not improve
# Epoch 00036: val_mean_squared_error did not improve
# lr changed to 0.00015009464841568844
# Epoch 00037: val_mean_squared_error did not improve
# Epoch 00038: val_mean_squared_error did not improve
# lr changed to 0.0001350851875031367
# Epoch 00039: val_mean_squared_error did not improve
# Epoch 00040: val_mean_squared_error did not improve
# lr changed to 0.00012157666351413355
# Epoch 00041: val_mean_squared_error did not improve
# Epoch 00042: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to model weights/bm_with_lookback_5_epochs_1000.better_weights.best.hdf5
# lr changed to 0.00010941899454337544
# Epoch 00043: val_mean_squared_error did not improve
# Epoch 00044: val_mean_squared_error did not improve
# lr changed to 9.847709443420172e-05
# Epoch 00045: val_mean_squared_error did not improve
# Epoch 00046: val_mean_squared_error did not improve
# lr changed to 8.862938630045391e-05
# Epoch 00047: val_mean_squared_error did not improve
# Epoch 00048: val_mean_squared_error did not improve
# lr changed to 7.976644701557234e-05
# Epoch 00049: val_mean_squared_error did not improve
# Epoch 00050: val_mean_squared_error did not improve
# lr changed to 7.178980231401511e-05
# Epoch 00051: val_mean_squared_error did not improve
# Epoch 00052: val_mean_squared_error did not improve
# lr changed to 6.461082011810504e-05
# Epoch 00053: val_mean_squared_error did not improve
# Epoch 00054: val_mean_squared_error did not improve
# lr changed to 5.8149741380475466e-05
# Epoch 00055: val_mean_squared_error did not improve
# Epoch 00056: val_mean_squared_error did not improve
# lr changed to 5.233476658759173e-05
# Epoch 00057: val_mean_squared_error did not improve
# Epoch 00058: val_mean_squared_error did not improve
# lr changed to 4.7101289601414466e-05
# Epoch 00059: val_mean_squared_error did not improve
# Epoch 00060: val_mean_squared_error did not improve
# lr changed to 4.239116096869111e-05
# Epoch 00061: val_mean_squared_error did not improve
# Epoch 00062: val_mean_squared_error did not improve
# lr changed to 3.815204618149437e-05
# Epoch 00063: val_mean_squared_error did not improve
# Epoch 00064: val_mean_squared_error did not improve
# lr changed to 3.4336842873017304e-05
# Epoch 00065: val_mean_squared_error did not improve
# Epoch 00066: val_mean_squared_error did not improve
# lr changed to 3.0903160222806036e-05
# Epoch 00067: val_mean_squared_error did not improve
# Epoch 00068: val_mean_squared_error did not improve
# lr changed to 2.7812844200525434e-05
# Epoch 00069: val_mean_squared_error did not improve
# Epoch 00070: val_mean_squared_error did not improve
# lr changed to 2.5031560107890984e-05
# Epoch 00071: val_mean_squared_error did not improve
# Epoch 00072: val_mean_squared_error did not improve
# lr changed to 2.2528404588229024e-05
# Epoch 00073: val_mean_squared_error did not improve
# Epoch 00074: val_mean_squared_error did not improve
# lr changed to 2.0275563474569936e-05
# Epoch 00075: val_mean_squared_error did not improve
# Epoch 00076: val_mean_squared_error did not improve
# lr changed to 1.8248007290821987e-05
# Epoch 00077: val_mean_squared_error did not improve
# Epoch 00078: val_mean_squared_error did not improve
# lr changed to 1.6423206398030745e-05
# Epoch 00079: val_mean_squared_error did not improve
# Epoch 00080: val_mean_squared_error did not improve
# lr changed to 1.4780885430809576e-05
# Epoch 00081: val_mean_squared_error did not improve
# Epoch 00082: val_mean_squared_error did not improve
# lr changed to 1.3302796560310526e-05
# Epoch 00083: val_mean_squared_error did not improve
# Epoch 00084: val_mean_squared_error did not improve
# lr changed to 1.1972517313552089e-05
# Epoch 00085: val_mean_squared_error did not improve
# Epoch 00086: val_mean_squared_error did not improve
# lr changed to 1.077526558219688e-05
# Epoch 00087: val_mean_squared_error did not improve
# Epoch 00088: val_mean_squared_error did not improve
# lr changed to 9.697739187686238e-06
# Epoch 00089: val_mean_squared_error did not improve
# Epoch 00090: val_mean_squared_error did not improve
# lr changed to 8.727965268917615e-06
# Epoch 00091: val_mean_squared_error did not improve
# Epoch 00092: val_mean_squared_error did not improve
# lr changed to 7.855168496462283e-06
# Epoch 00093: val_mean_squared_error did not improve
# Epoch 00094: val_mean_squared_error did not improve
# lr changed to 7.069651564961533e-06
# Epoch 00095: val_mean_squared_error did not improve
# Epoch 00096: val_mean_squared_error did not improve
# lr changed to 6.362686326610856e-06
# Epoch 00097: val_mean_squared_error did not improve
# Epoch 00098: val_mean_squared_error did not improve
# lr changed to 5.726417612095247e-06
# Epoch 00099: val_mean_squared_error did not improve
# Epoch 00100: val_mean_squared_error did not improve
# lr changed to 5.15377605552203e-06
# Epoch 00101: val_mean_squared_error did not improve
# Epoch 00102: val_mean_squared_error did not improve
# lr changed to 4.638398286260781e-06
# Epoch 00103: val_mean_squared_error did not improve
# Epoch 00104: val_mean_squared_error did not improve
# lr changed to 4.174558580416488e-06
# Epoch 00105: val_mean_squared_error did not improve
# Epoch 00106: val_mean_squared_error did not improve
# lr changed to 3.7571025586657926e-06
# Epoch 00107: val_mean_squared_error did not improve
# Epoch 00108: val_mean_squared_error did not improve
# lr changed to 3.381392343726475e-06
# Epoch 00109: val_mean_squared_error did not improve
# Epoch 00110: val_mean_squared_error did not improve
# lr changed to 3.043253150281089e-06
# Epoch 00111: val_mean_squared_error did not improve
# Epoch 00112: val_mean_squared_error did not improve
# lr changed to 2.7389278557166107e-06
# Epoch 00113: val_mean_squared_error did not improve
# Epoch 00114: val_mean_squared_error did not improve
# lr changed to 2.465035049681319e-06
# Epoch 00115: val_mean_squared_error did not improve
# Epoch 00116: val_mean_squared_error did not improve
# lr changed to 2.2185315856404485e-06
# Epoch 00117: val_mean_squared_error did not improve
# Epoch 00118: val_mean_squared_error did not improve
# lr changed to 1.996678406612773e-06
# Epoch 00119: val_mean_squared_error did not improve
# Epoch 00120: val_mean_squared_error did not improve
# lr changed to 1.7970104636333418e-06
# Epoch 00121: val_mean_squared_error did not improve
# Epoch 00122: val_mean_squared_error did not improve
# lr changed to 1.6173093968063768e-06
# Epoch 00123: val_mean_squared_error did not improve
# Epoch 00124: val_mean_squared_error did not improve
# lr changed to 1.4555784673575544e-06
# Epoch 00125: val_mean_squared_error did not improve
# Epoch 00126: val_mean_squared_error did not improve
# lr changed to 1.3100206615490606e-06
# Epoch 00127: val_mean_squared_error did not improve
# Epoch 00128: val_mean_squared_error did not improve
# lr changed to 1.179018636321416e-06
# Epoch 00129: val_mean_squared_error did not improve
# Epoch 00130: val_mean_squared_error did not improve
# lr changed to 1.0611168136165362e-06
# Epoch 00131: val_mean_squared_error did not improve
# Epoch 00132: val_mean_squared_error did not improve
# lr changed to 9.550051117912518e-07
# Epoch 00133: val_mean_squared_error did not improve
# Epoch 00134: val_mean_squared_error did not improve
# lr changed to 8.595046210757574e-07
# Epoch 00135: val_mean_squared_error did not improve
# Epoch 00136: val_mean_squared_error did not improve
# lr changed to 7.735541487363662e-07
# Epoch 00137: val_mean_squared_error did not improve
# Epoch 00138: val_mean_squared_error did not improve
# lr changed to 6.961987082831911e-07
# Epoch 00139: val_mean_squared_error did not improve
# Epoch 00140: val_mean_squared_error did not improve
# lr changed to 6.265788272230566e-07
# Epoch 00141: val_mean_squared_error did not improve
# Epoch 00142: val_mean_squared_error did not improve
# lr changed to 5.639209291530278e-07
# Epoch 00143: val_mean_squared_error did not improve
# Epoch 00144: val_mean_squared_error did not improve
# lr changed to 5.075288413536328e-07
# Epoch 00145: val_mean_squared_error did not improve
# Epoch 00146: val_mean_squared_error did not improve
# lr changed to 4.5677596745008485e-07
# Epoch 00147: val_mean_squared_error did not improve
# Epoch 00148: val_mean_squared_error did not improve
# lr changed to 4.110983809368918e-07
# Epoch 00149: val_mean_squared_error did not improve
# Epoch 00150: val_mean_squared_error did not improve
# lr changed to 3.6998853261138723e-07
# Epoch 00151: val_mean_squared_error did not improve
# Epoch 00152: val_mean_squared_error did not improve
# lr changed to 3.3298967423434077e-07
# Epoch 00153: val_mean_squared_error did not improve
# Epoch 00154: val_mean_squared_error did not improve
# lr changed to 2.9969071704272213e-07
# Epoch 00155: val_mean_squared_error did not improve
# Epoch 00156: val_mean_squared_error did not improve
# lr changed to 2.6972165301231144e-07
# Epoch 00157: val_mean_squared_error did not improve
# Epoch 00158: val_mean_squared_error did not improve
# lr changed to 2.427494877110803e-07
# Epoch 00159: val_mean_squared_error did not improve
# Epoch 00160: val_mean_squared_error did not improve
# lr changed to 2.1847453126611072e-07
# Epoch 00161: val_mean_squared_error did not improve
# Epoch 00162: val_mean_squared_error did not improve
# lr changed to 1.9662707302359196e-07
# Epoch 00163: val_mean_squared_error did not improve
# Epoch 00164: val_mean_squared_error did not improve
# lr changed to 1.769643631632789e-07
# Epoch 00165: val_mean_squared_error did not improve
# Epoch 00166: val_mean_squared_error did not improve
# lr changed to 1.5926792684695101e-07
# Epoch 00167: val_mean_squared_error did not improve
# Epoch 00168: val_mean_squared_error did not improve
# lr changed to 1.433411341622559e-07
# Epoch 00169: val_mean_squared_error did not improve
# Epoch 00170: val_mean_squared_error did not improve
# lr changed to 1.2900702586193802e-07
# Epoch 00171: val_mean_squared_error did not improve
# Epoch 00172: val_mean_squared_error did not improve
# lr changed to 1.1610631815983652e-07
# Epoch 00173: val_mean_squared_error did not improve
# Epoch 00174: val_mean_squared_error did not improve
# lr changed to 1.0449568890180672e-07
# Epoch 00175: val_mean_squared_error did not improve
# Epoch 00176: val_mean_squared_error did not improve
# lr changed to 9.404612129060297e-08
# Epoch 00177: val_mean_squared_error did not improve
# Epoch 00178: val_mean_squared_error did not improve
# lr changed to 8.464150980103113e-08
# Epoch 00179: val_mean_squared_error did not improve
# Epoch 00180: val_mean_squared_error did not improve
# lr changed to 7.617736201837033e-08
# Epoch 00181: val_mean_squared_error did not improve
# Epoch 00182: val_mean_squared_error did not improve
# lr changed to 6.855962837448715e-08
# Epoch 00183: val_mean_squared_error did not improve
# Epoch 00184: val_mean_squared_error did not improve
# lr changed to 6.17036661765269e-08
# Epoch 00185: val_mean_squared_error did not improve
# Epoch 00186: val_mean_squared_error did not improve
# lr changed to 5.553329955887421e-08
# Epoch 00187: val_mean_squared_error did not improve
# Epoch 00188: val_mean_squared_error did not improve
# lr changed to 4.997996896349832e-08
# Epoch 00189: val_mean_squared_error did not improve
# Epoch 00190: val_mean_squared_error did not improve
# lr changed to 4.4981973346125416e-08
# Epoch 00191: val_mean_squared_error did not improve
# Epoch 00192: val_mean_squared_error did not improve
# lr changed to 4.0483776331257104e-08
# Epoch 00193: val_mean_squared_error did not improve
# Epoch 00194: val_mean_squared_error did not improve
# lr changed to 3.6435398698131394e-08
# Epoch 00195: val_mean_squared_error did not improve
# Epoch 00196: val_mean_squared_error did not improve
# lr changed to 3.279185882831826e-08
# Epoch 00197: val_mean_squared_error did not improve
# Epoch 00198: val_mean_squared_error did not improve
# lr changed to 2.9512673904719123e-08
# Epoch 00199: val_mean_squared_error did not improve
# Epoch 00200: val_mean_squared_error did not improve
# lr changed to 2.656140587475875e-08
# Epoch 00201: val_mean_squared_error did not improve
# Epoch 00202: val_mean_squared_error did not improve
# lr changed to 2.3905264967538643e-08
# Epoch 00203: val_mean_squared_error did not improve
# Epoch 00204: val_mean_squared_error did not improve
# lr changed to 2.151473879052901e-08
# Epoch 00205: val_mean_squared_error did not improve
# Epoch 00206: val_mean_squared_error did not improve
# lr changed to 1.9363264591731878e-08
# Epoch 00207: val_mean_squared_error did not improve
# Epoch 00208: val_mean_squared_error did not improve
# lr changed to 1.7426938292430804e-08
# Epoch 00209: val_mean_squared_error did not improve
# Epoch 00210: val_mean_squared_error did not improve
# lr changed to 1.5684244303315608e-08
# Epoch 00211: val_mean_squared_error did not improve
# Epoch 00212: val_mean_squared_error did not improve
# lr changed to 1.411582051247251e-08
# Epoch 00213: val_mean_squared_error did not improve
# Epoch 00214: val_mean_squared_error did not improve
# lr changed to 1.270423846122526e-08
# Epoch 00215: val_mean_squared_error did not improve
# Epoch 00216: val_mean_squared_error did not improve
# lr changed to 1.1433814695038791e-08
# Epoch 00217: val_mean_squared_error did not improve
# Epoch 00218: val_mean_squared_error did not improve
# lr changed to 1.029043330547097e-08
# Epoch 00219: val_mean_squared_error did not improve
# Epoch 00220: val_mean_squared_error did not improve
# lr changed to 9.261390054859931e-09
# Epoch 00221: val_mean_squared_error did not improve
# Epoch 00222: val_mean_squared_error did not improve
# lr changed to 8.335250889501823e-09
# Epoch 00223: val_mean_squared_error did not improve
# Epoch 00224: val_mean_squared_error did not improve
# lr changed to 7.501725640679525e-09
# Epoch 00225: val_mean_squared_error did not improve
# Epoch 00226: val_mean_squared_error did not improve
# lr changed to 6.751552916739456e-09
# Epoch 00227: val_mean_squared_error did not improve
# Epoch 00228: val_mean_squared_error did not improve
# lr changed to 6.076397784937626e-09
# Epoch 00229: val_mean_squared_error did not improve
# Epoch 00230: val_mean_squared_error did not improve
# lr changed to 5.468757846571748e-09
# Epoch 00231: val_mean_squared_error did not improve
# Epoch 00232: val_mean_squared_error did not improve
# lr changed to 4.9218821018826025e-09
# Epoch 00233: val_mean_squared_error did not improve
# Epoch 00234: val_mean_squared_error did not improve
# lr changed to 4.4296938117582845e-09
# Epoch 00235: val_mean_squared_error did not improve
# Epoch 00236: val_mean_squared_error did not improve
# lr changed to 3.986724550486542e-09
# Epoch 00237: val_mean_squared_error did not improve
# Epoch 00238: val_mean_squared_error did not improve
# lr changed to 3.5880522553100038e-09
# Epoch 00239: val_mean_squared_error did not improve
# Epoch 00240: val_mean_squared_error did not improve
# lr changed to 3.2292470697470322e-09
# Epoch 00241: val_mean_squared_error did not improve
# Epoch 00242: val_mean_squared_error did not improve
# lr changed to 2.9063223827563434e-09
# Epoch 00243: val_mean_squared_error did not improve
# Epoch 00244: val_mean_squared_error did not improve
# lr changed to 2.6156900645446514e-09
# Epoch 00245: val_mean_squared_error did not improve
# Epoch 00246: val_mean_squared_error did not improve
# lr changed to 2.354121098058215e-09
# Epoch 00247: val_mean_squared_error did not improve
# Epoch 00248: val_mean_squared_error did not improve
# lr changed to 2.118709008236408e-09
# Epoch 00249: val_mean_squared_error did not improve
# Epoch 00250: val_mean_squared_error did not improve
# lr changed to 1.906838087428753e-09
# Epoch 00251: val_mean_squared_error did not improve
# Epoch 00252: val_mean_squared_error did not improve
# lr changed to 1.7161542187338341e-09
# Epoch 00253: val_mean_squared_error did not improve
# Epoch 00254: val_mean_squared_error did not improve
# lr changed to 1.5445387968604508e-09
# Epoch 00255: val_mean_squared_error did not improve
# Epoch 00256: val_mean_squared_error did not improve
# lr changed to 1.3900849471504273e-09
# Epoch 00257: val_mean_squared_error did not improve
# Epoch 00258: val_mean_squared_error did not improve
# lr changed to 1.2510764424433774e-09
# Epoch 00259: val_mean_squared_error did not improve
# Epoch 00260: val_mean_squared_error did not improve
# lr changed to 1.125968818183054e-09
# Epoch 00261: val_mean_squared_error did not improve
# Epoch 00262: val_mean_squared_error did not improve
# lr changed to 1.0133719863247848e-09
# Epoch 00263: val_mean_squared_error did not improve
# Epoch 00264: val_mean_squared_error did not improve
# lr changed to 9.120347477242774e-10
# Epoch 00265: val_mean_squared_error did not improve
# Epoch 00266: val_mean_squared_error did not improve
# lr changed to 8.208312529678353e-10
# Epoch 00267: val_mean_squared_error did not improve
# Epoch 00268: val_mean_squared_error did not improve
# lr changed to 7.387481126830409e-10
# Epoch 00269: val_mean_squared_error did not improve
# Epoch 00270: val_mean_squared_error did not improve
# lr changed to 6.648733064107404e-10
# Epoch 00271: val_mean_squared_error did not improve
# Epoch 00272: val_mean_squared_error did not improve
# lr changed to 5.983859907576772e-10
# Epoch 00273: val_mean_squared_error did not improve
# Epoch 00274: val_mean_squared_error did not improve
# lr changed to 5.385474066699203e-10
# Epoch 00275: val_mean_squared_error did not improve
# Epoch 00276: val_mean_squared_error did not improve
# lr changed to 4.846926859869428e-10
# Epoch 00277: val_mean_squared_error did not improve
# Epoch 00278: val_mean_squared_error did not improve
# lr changed to 4.362234073962412e-10
# Epoch 00279: val_mean_squared_error did not improve
# Epoch 00280: val_mean_squared_error did not improve
# lr changed to 3.926010766486243e-10
# Epoch 00281: val_mean_squared_error did not improve
# Epoch 00282: val_mean_squared_error did not improve
# lr changed to 3.5334095649375285e-10
# Epoch 00283: val_mean_squared_error did not improve
# Epoch 00284: val_mean_squared_error did not improve
# lr changed to 3.180068708363848e-10
# Epoch 00285: val_mean_squared_error did not improve
# Epoch 00286: val_mean_squared_error did not improve
# lr changed to 2.862061837527463e-10
# Epoch 00287: val_mean_squared_error did not improve
# Epoch 00288: val_mean_squared_error did not improve
# lr changed to 2.5758555288746264e-10
# Epoch 00289: val_mean_squared_error did not improve
# Epoch 00290: val_mean_squared_error did not improve
# lr changed to 2.3182700759072362e-10
# Epoch 00291: val_mean_squared_error did not improve
# Epoch 00292: val_mean_squared_error did not improve
# lr changed to 2.0864430183564764e-10
# Epoch 00293: val_mean_squared_error did not improve
# Epoch 00294: val_mean_squared_error did not improve
# lr changed to 1.8777986665607927e-10
# Epoch 00295: val_mean_squared_error did not improve
# Epoch 00296: val_mean_squared_error did not improve
# lr changed to 1.6900187499446773e-10
# Epoch 00297: val_mean_squared_error did not improve
# Epoch 00298: val_mean_squared_error did not improve
# lr changed to 1.5210168125001646e-10
# Epoch 00299: val_mean_squared_error did not improve
# Epoch 00300: val_mean_squared_error did not improve
# lr changed to 1.36891510627013e-10
# Epoch 00301: val_mean_squared_error did not improve
# Epoch 00302: val_mean_squared_error did not improve
# lr changed to 1.232023608133126e-10
# Epoch 00303: val_mean_squared_error did not improve
# Epoch 00304: val_mean_squared_error did not improve
# lr changed to 1.1088212847898405e-10
# Epoch 00305: val_mean_squared_error did not improve
# Epoch 00306: val_mean_squared_error did not improve
# lr changed to 9.979391688008654e-11
# Epoch 00307: val_mean_squared_error did not improve
# Epoch 00308: val_mean_squared_error did not improve
# lr changed to 8.981452456757743e-11
# Epoch 00309: val_mean_squared_error did not improve
# Epoch 00310: val_mean_squared_error did not improve
# lr changed to 8.083307148631925e-11
# Epoch 00311: val_mean_squared_error did not improve
# Epoch 00312: val_mean_squared_error did not improve
# lr changed to 7.274976246418597e-11
# Epoch 00313: val_mean_squared_error did not improve
# Epoch 00314: val_mean_squared_error did not improve
# lr changed to 6.547478809126872e-11
# Epoch 00315: val_mean_squared_error did not improve
# Epoch 00316: val_mean_squared_error did not improve
# lr changed to 5.892730678414005e-11
# Epoch 00317: val_mean_squared_error did not improve
# Epoch 00318: val_mean_squared_error did not improve
# lr changed to 5.303457673022649e-11
# Epoch 00319: val_mean_squared_error did not improve
# Epoch 00320: val_mean_squared_error did not improve
# lr changed to 4.773111905720384e-11
# Epoch 00321: val_mean_squared_error did not improve
# Epoch 00322: val_mean_squared_error did not improve
# lr changed to 4.295800590248256e-11
# Epoch 00323: val_mean_squared_error did not improve
# Epoch 00324: val_mean_squared_error did not improve
# lr changed to 3.866220468773385e-11
# Epoch 00325: val_mean_squared_error did not improve
# Epoch 00326: val_mean_squared_error did not improve
# lr changed to 3.479598484346092e-11
# Epoch 00327: val_mean_squared_error did not improve
# Epoch 00328: val_mean_squared_error did not improve
# lr changed to 3.1316386983615274e-11
# Epoch 00329: val_mean_squared_error did not improve
# Epoch 00330: val_mean_squared_error did not improve
# lr changed to 2.818474828525375e-11
# Epoch 00331: val_mean_squared_error did not improve
# Epoch 00332: val_mean_squared_error did not improve
# lr changed to 2.5366273144478147e-11
# Epoch 00333: val_mean_squared_error did not improve

# %%
dill.dump(err_decay_lr.history, open("model weights/"+simname+"lr_decay_history.dat", 'wb'))

# %%
simname = "bm_with_lookback_5_epochs_500"

# %%
err_lr_decay_history = dill.load(open("model weights/"+simname+"lr_decay_history.dat", 'rb'))

# %% [markdown]
# ## Check testing errors after decaying learning rate
#  - here error chart resolution is better, as we start from the trained model

# %%
print("smallest validation MAE: ", min(err_history['val_mean_absolute_error']))
print("smallest validation MSE: ", min(err_history['val_mean_squared_error']))
print("decay lr: smallest validation MAE: ", min(err_lr_decay_history['val_mean_absolute_error']))
print("decay lr: smallest validation MSE: ", min(err_lr_decay_history['val_mean_squared_error']))
# Out:
# smallest validation MAE:  0.00388927032374
# smallest validation MSE:  3.37022721573e-05
# decay lr: smallest validation MAE:  0.00393891990398
# decay lr: smallest validation MSE:  3.29076526996e-05

# %%
for error_metric in list(err_lr_decay_history.keys()):
    if 'val' not in error_metric:
        plt.figure(figsize=(40,10))
        plt.plot(err_lr_decay_history[error_metric]) # this is for train
        plt.plot(err_lr_decay_history['val_' + error_metric]) # this is for test
        plt.title(error_metric, fontsize=30)
        plt.ylabel(error_metric)
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left', fontsize=30)
        plt.show()

# %% [markdown]
# The variance should have improved slightly. However, unless the mean absolute error is small enough, the model is not usable in practice. This is mainly due to only using the sample data for training and limiting epoch to a few hundreds.

# %% [markdown]
# ## Check scaled predictions

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#simname = "500_epochs_40_lookback"
print(simname)
model.load_weights("model weights/"+simname+".better_weights.best.hdf5")
# Out:
# bm_with_lookback_5_epochs_1000

# %%
if not runLSTMBinary:
    # Benchmark
    model.load_weights("model weights/"+simname+".better_weights.best.hdf5")

    X_test_pred = model.predict(X_test) # predict on testset

    predictions = pd.DataFrame()
    predictions['predicted'] = pd.Series(np.reshape(X_test_pred, (X_test_pred.shape[0])))
    predictions['actual'] = y_test
    predictions = predictions.astype(float)


    fig, axarr = plt.subplots(1, 2, figsize=(15,5)) #1 row, 2 cols, x, y
    i_row, icol = 0,0
    fig.suptitle("predictions on test set", fontsize=20)
    predictions.plot(ax=axarr[icol])
    axarr[icol].set_title("Predicted close vs actual over time")

    icol +=1
    predictions['diff'] = predictions['actual'] - predictions['predicted']
    sns.distplot(predictions['diff'], ax=axarr[icol]);
    axarr[icol].set_title('Distribution of differences: actual minus predicted')
    plt.show()

    print("MSE scaled : ", mean_squared_error(predictions['predicted'].values, predictions['actual'].values))
    print("MAE scaled: ", mean_absolute_error(predictions['predicted'].values, predictions['actual'].values))
    #predictions['diff'].describe()
# Out:
# MSE scaled :  3.88532359806e-05
# MAE scaled:  0.00508196881954

# %% [markdown]
# ## Check unscaled predictions for regression

# %%
#unscale predictions and actuals
X_test_pred = model.predict(X_test)
X_test_pred_unscaled = y_scaler.inverse_transform(X_test_pred)
X_test_pred_unscaled = np.reshape(X_test_pred_unscaled, (X_test_pred_unscaled.shape[0]))

actual = y_scaler.inverse_transform(np.reshape(y_test, (y_test.shape[0], 1)))
actual = np.reshape(actual, (actual.shape[0]))

predictions = pd.DataFrame()
predictions['predicted'] = pd.Series(X_test_pred_unscaled)
predictions['close_bid'] = pd.Series(actual)


# get low and high bid from untransformed dataframe
p = df[-X_test_pred_unscaled.shape[0]:].copy()
predictions.index = p.index # get the date index  from the dataframe
predictions = predictions.astype(float)
predictions = predictions.merge(p[['low_bid', 'high_bid']], right_index=True, left_index=True)

# %%
if not runLSTMBinary:
    fig, axarr = plt.subplots(1, 4, figsize=(5,10)) #1 row, 2 cols, x, y
    irow, icol = 0,0

    predictions.plot(x=predictions.index, y='close_bid', c='red', figsize=(40,10), ax=axarr[icol])
    predictions.plot(x=predictions.index, y='predicted', c='blue', figsize=(40,10), ax=axarr[icol])
    index = [str(item) for item in predictions.index]
    #plt.fill_between(x=predictions.index, y1='low_bid', y2='high_bid', data=predictions, alpha=0.4)
    axarr[icol].set_title('Prediction vs Actual (low and high as blue region)')

    icol += 1
    predictions['pred_minus_actual'] = predictions['predicted'] - predictions['close_bid']
    
    sns.distplot(predictions['pred_minus_actual'], ax=axarr[icol]);
    axarr[icol].set_title('Distribution of differences between actual and prediction ')
    #plt.savefig(simname+"__histogram__actual_minus_pred.jpg")

    icol += 1
    sns.kdeplot(predictions["pred_minus_actual"], predictions["predicted"], kind="kde", space=0, ax=axarr[icol])
    #sns.jointplot(predictions["diff"], predictions["predicted"], kind="kde", space=0, ax=axarr[icol]) # must be by itself
    axarr[icol].set_title('Distribution of error and price')
    #plt.savefig(simname+"__contour__error_v_price.jpg")


    icol +=1
    predictions['correct'] = (predictions['predicted'] <= predictions['high_bid']) & (predictions['predicted'] >= predictions['low_bid'])
    predictions.correct.value_counts().plot(kind="bar", ax=axarr[icol])
    axarr[icol].set_title("True (in high low range), False prediction counts")

    plt.show()

    print("MSE unscaled : ", mean_squared_error(predictions['predicted'].values, predictions['close_bid'].values))
    print("MAE unscaled: ", mean_absolute_error(predictions['predicted'].values, predictions['close_bid'].values))
    #predictions['pred_minus_actual'].describe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'kind', 'space'
#   s)
# MSE unscaled :  3.0596181152e-07
# MAE unscaled:  0.000450971142558

# %%
if not runLSTMBinary:
    df_unscaled = df_scaler.inverse_transform(df_scaled)

    X_test_unscaled = df_scaler.inverse_transform(np.reshape(X_test[:,0,:], (X_test.shape[0], X_test.shape[2])))
    y_prev = X_test_unscaled[:,idx_close_bid]

    y_train_unscaled =  y_scaler.inverse_transform(np.reshape(y_train, (y_train.shape[0], 1)))
    y_train_unscaled = np.reshape(y_train_unscaled, (y_train_unscaled.shape[0]))

    y_test_unscaled =  y_scaler.inverse_transform(np.reshape(y_test, (y_test.shape[0], 1)))
    y_test_unscaled = np.reshape(y_test_unscaled, (y_test_unscaled.shape[0]))


    X_train_pred = model.predict(X_train)
    X_train_pred_unscaled = y_scaler.inverse_transform(X_train_pred)
    X_train_pred_unscaled = np.reshape(X_train_pred_unscaled, (X_train_pred_unscaled.shape[0]))

    #check_shape(df,y_train_unscaled, y_test_unscaled, X_train_pred_unscaled, X_test_pred_unscaled, y_prev)

    df_err = check_error_metrics(df
                        , y_train_unscaled, y_test_unscaled
                        , X_train_pred_unscaled, X_test_pred_unscaled
                        , y_prev)
    #idx_close_bid
    #X_test[:,0,idx_close_bid].shape
# Out:
# ['mse train', 4.2797285e-07]
# ['mse test', 3.0596181e-07]
# ['mae train', 0.00044696938]
# ['mae test', 0.00045097113]
# ['how often sign of price change is same', 0.65100671140939592]
# ['if same sign, how often are actual returns better than 1 bp absolute in both directions', 86.597938144329902]
# ['if same sign, how often are actual returns better than predicted in both directions', 98.969072164948457]
# ['if not same sign, how often is actual worse than -1 bp return from predicted in both directions', 0.98076923076923073]
# ['if not same sign, how often is actual worse than -1 bp return absolute in both directions', 0.80769230769230771]

# %%
simname
# Out:
# 'bm_with_lookback_5_epochs_1000'

# %% [markdown]
# ## check binary predictions and confusion matrix

# %%
if runLSTMBinary:
    from sklearn.metrics import confusion_matrix
    #check_shape(y_test, model.predict(X_test))
    y_pred_class = np.argmax(model.predict(X_test), axis=1)  # find position of largest argument
    y_test_class = np.argmax(y_test, axis=1)
    test_acc = 100 * np.sum(y_pred_class==y_test_class) / len(y_test)
    print("acc ", test_acc )
    confusion_matrix(y_pred_class, y_test_class)

# %% [markdown]
# Sim results:
# - runing at 500 epochs converges a bit better. seems extra features need more time.

# %% [markdown]
# # Check logs and compare to previous simulations

# %%
log = True
initval=False
#sim_desc = "500 iterations, lookback 40"
#simname = "500_epoch_lookback_40"

# %%
list_stats=OrderedDict()

if log:
    #simname= "linear regression"
    #sim_desc = "1 row lookback"
    
    dict_err= OrderedDict(zip(df_err[0], df_err[1]))    
    list_stats=OrderedDict()    
    list_stats["simname"] = simname
    list_stats["sim_desc"] = sim_desc
    list_stats["MSE"] = dict_err["mse test"]
    list_stats["MAE"] = dict_err["mae test"]
    
    differences_described = predictions["pred_minus_actual"].describe()

    list_stats.update(OrderedDict(differences_described))
    list_stats.update(dict_err)
    
    results = pd.DataFrame([list_stats])
    #results.to_excel("log_results.xlsx")
    if os.path.isfile("log_results.xlsx"):
        log_results = pd.read_excel("log_results.xlsx")
        log_results.loc[len(log_results),:] = list_stats.values()
        log_results.to_excel("log_results.xlsx")
    #log_results

# %%
log_results = pd.read_excel("log_results.xlsx")
log_results = log_results.iloc[[1,5,13, 14]].T

# %%
df_to_image(log_results, "report graphs/", "simlog")
# Out:
# 0

# %%
log_results
# Out:
#                                                                                                    1   \
# simname                                                                                     bm_kaggle
# sim_desc                                            kaggle bm has 200 epoch and batch size 500 and...
# MSE                                                                                       1.20446e-07
# MAE                                                                                       0.000278994
# count                                                                                             149
# mean                                                                                      9.99558e-05
# std                                                                                       0.000333468
# min                                                                                       -0.00100839
# 25%                                                                                       -0.00011158
# 50%                                                                                       0.000176191
# 75%                                                                                       0.000239134
# max                                                                                       0.000836968
# mse train                                                                                 5.39973e-07
# mse test                                                                                  1.20446e-07
# mae train                                                                                 0.000453188
# mae test                                                                                  0.000278994
# how often sign of price change is same                                                       0.657718
# if same sign, how often are actual returns bett...                                            92.8571
# if same sign, how often are actual returns bett...                                                100
# if not same sign, how often is actual worse tha...                                           0.960784
# if not same sign, how often is actual worse tha...                                           0.117647
#
#                                                                                            5   \
# simname                                                               kaggle param my dataset
# sim_desc                                            \n    kaggle params with my dataset\n
# MSE                                                                               5.59631e-07
# MAE                                                                               0.000571841
# count                                                                                     149
# mean                                                                             -0.000226223
# std                                                                               0.000715464
# min                                                                                -0.0018394
# 25%                                                                              -0.000689983
# 50%                                                                              -0.000272751
# 75%                                                                               8.13007e-05
# max                                                                                0.00250375
# mse train                                                                         9.09057e-07
# mse test                                                                          5.59631e-07
# mae train                                                                         0.000640386
# mae test                                                                          0.000571841
# how often sign of price change is same                                               0.865772
# if same sign, how often are actual returns bett...                                    96.8992
# if same sign, how often are actual returns bett...                                        100
# if not same sign, how often is actual worse tha...                                        0.9
# if not same sign, how often is actual worse tha...                                        0.8
#
#                                                                                            13  \
# simname                                                         bm_with_lookback_5_epochs_500
# sim_desc                                            \n    kaggle params with my dataset\n
# MSE                                                                                1.3067e-07
# MAE                                                                               0.000272417
# count                                                                                     149
# mean                                                                             -8.11183e-06
# std                                                                               0.000362611
# min                                                                              -0.000883698
# 25%                                                                              -0.000214458
# 50%                                                                              -4.82798e-05
# 75%                                                                               0.000186682
# max                                                                                0.00134325
# mse train                                                                         4.61448e-07
# mse test                                                                           1.3067e-07
# mae train                                                                         0.000460343
# mae test                                                                          0.000272417
# how often sign of price change is same                                               0.812081
# if same sign, how often are actual returns bett...                                    87.6033
# if same sign, how often are actual returns bett...                                        100
# if not same sign, how often is actual worse tha...                                   0.892857
# if not same sign, how often is actual worse tha...                                   0.714286
#
#                                                                                            14
# simname                                                        bm_with_lookback_5_epochs_1000
# sim_desc                                            \n    kaggle params with my dataset\n
# MSE                                                                               3.05962e-07
# MAE                                                                               0.000450971
# count                                                                                     149
# mean                                                                              0.000421663
# std                                                                               0.000359204
# min                                                                              -0.000402927
# 25%                                                                                0.00016892
# 50%                                                                               0.000408173
# 75%                                                                               0.000617623
# max                                                                                0.00176418
# mse train                                                                         4.27973e-07
# mse test                                                                          3.05962e-07
# mae train                                                                         0.000446969
# mae test                                                                          0.000450971
# how often sign of price change is same                                               0.651007
# if same sign, how often are actual returns bett...                                    86.5979
# if same sign, how often are actual returns bett...                                    98.9691
# if not same sign, how often is actual worse tha...                                   0.980769
# if not same sign, how often is actual worse tha...                                   0.807692
